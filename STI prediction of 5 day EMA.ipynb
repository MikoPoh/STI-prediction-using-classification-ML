# %%
# Importing packages
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import log_loss
import xgboost as xgb

# %% [markdown]
# # 1. Retrieving STI history data from yahoo finance
# ### -Retrieving history of STI as ticker and extract past history from it
# ### -History extracted consist of every record yahoo finance has, with period set as max
# ### -Dividends and stock splits are dropped since they are of no used

# %%
# Loading STI's history into a dataframe
sti= yf.Ticker("^sti")
sti_df = sti.history(period='max')
sti_df.drop(["Dividends","Stock Splits"], axis=1, inplace=True)
sti_df
# Out:
#                    Open         High          Low        Close     Volume
# Date
# 1987-12-28   824.400024   824.400024   824.400024   824.400024          0
# 1987-12-29   810.900024   810.900024   810.900024   810.900024          0
# 1987-12-30   823.200012   823.200012   823.200012   823.200012          0
# 1988-01-04   833.599976   833.599976   833.599976   833.599976          0
# 1988-01-05   879.299988   879.299988   879.299988   879.299988          0
# ...                 ...          ...          ...          ...        ...
# 2022-11-28  3241.689941  3248.689941  3221.889893  3240.060059  234267900
# 2022-11-29  3235.340088  3277.010010  3232.379883  3276.360107  261703800
# 2022-11-30  3279.860107  3290.560059  3270.030029  3290.489990  460598500
# 2022-12-01  3306.489990  3313.800049  3288.459961  3292.729980  278203400
# 2022-12-02  3287.229980  3287.229980  3259.139893  3259.139893  201011300
#
# [8725 rows x 5 columns]

# %% [markdown]
# # 2. Exploratory data analysis and feature engineering

# %% [markdown]
# ## 2.1 Checking any missing data or null values and correlation between columns

# %%
# To have a quick understand of the data
sti_df.describe() # Some volume values are 0 which does not make sense and will be remove later on
# Out:
#               Open         High          Low        Close        Volume
# count  8725.000000  8725.000000  8725.000000  8725.000000  8.725000e+03
# mean   2350.624397  2362.311594  2337.971800  2350.047382  9.995847e+07
# std     749.055896   751.932317   745.681364   748.782332  1.248053e+08
# min     805.140015   809.869995   800.270020   805.039978  0.000000e+00
# 25%    1679.479980  1692.699951  1665.540039  1679.390015  0.000000e+00
# 50%    2301.800049  2311.699951  2287.699951  2300.699951  3.550700e+07
# 75%    3089.909912  3104.250000  3074.389893  3089.489990  1.888355e+08
# max    3899.290039  3906.159912  3852.689941  3875.770020  1.472752e+09

# %%
# Checking of na present
sti_df.isna().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %% [markdown]
# # 2.2 Featured enginerring
# ### Close will be used as main focus for prediction. The following list of indicators will be used to create new features:
# #### 1. Exponential moving average (EMA)
# #### 2. Moving average convergence/divergence (MACD)
# #### 3. Stochastic
# #### 4. Force index

# %% [markdown]
# ## 2.2.1 Creating functions to input features.
# ### Functions created are able to calculate with different input range of period such as from 2 periods to 100 periods and above.
# ### Periods here refers to timeframe being looked at such as days, hours or minutes.
# ### For this model, day is used as the period.

# %%
def ema(file_name, period, price, smoothing = 2, column_name="ema_period"):
    
    """
    Calculation of EMA is as follows:

    EMA = (price * (smoothing / (1 + duration)) + previous_ema * (1 - (smoothing / (1 + duration)))

    """
    previous_ema = file_name.loc[:period, price].mean() #Getting average to be use as first ema
    
    ema_list = [previous_ema] # Storing first ema as a list and to store other ema values

    for i in range(period-1):
        #Insert 0 into elements before first EMA as first number period of values will not have ema values
        ema_list.insert(0, 0)
    
    # Calculating EMA for the rest
    for row_num in range(period, len(file_name[price])):
        current_price = file_name.loc[row_num, price]
        ema_temp = current_price * (smoothing / (1 + period)) + previous_ema * (1 - (smoothing / (1 + period)))
        previous_ema = ema_temp
        ema_list.append(ema_temp) # Appending of ema into list

    # Adding new column and add ema to it    
    file_name[f"{column_name}_{period}"] = ema_list

def macd(file_name):
    """
    Calculation for MACD as follows:
    MACD = ema_period_12 - ema_period_26
    Signal = ema_period_9 of MACD
    MACD_histogram = MACD - Signal

    Make sure dataframe has column "ema_period_26" and "ema_period_12"
    """

    file_name["macd"] = file_name["ema_period_12"] - file_name["ema_period_26"]
    ema(file_name, period=9, price="macd", column_name="signal_of_macd")
    file_name["macd_histogram"] = file_name["macd"] - file_name["signal_of_macd_9"]


def stochastic(file_name, period = 14, price = "Close"):
    """
    Calculation for stochastic is ((Closing_price - period_low) / (period_high - period_low)) * 100
    Period is define by user, default setting is 14
    Additional 2 columns will be created to show the high and low of the defined period
    """
    file_name[f"high_period_{period}"] = file_name[price].rolling(period).max()
    file_name[f"low_period_{period}"] = file_name[price].rolling(period).min()

    file_name[f"stochastic_period_{period}"] = ((file_name[price] - file_name[f"low_period_{period}"]) / (file_name[f"high_period_{period}"] - file_name[f"low_period_{period}"])) * 100

def force_index(file_name, period = 1, price = "Close"):
    """
    Default price use is "Close"
    Force Index(1) = {Close (current period)  -  Close (prior period)} x Volume
    Force Index(13) = 13-period EMA of Force Index(1)
    Change from yesterday close and today close will be calculate into a new column "close_diff"
    """
    file_name["close_diff"] = file_name[price].diff()
    file_name[f"force_index_period_{period}"] = file_name["close_diff"] * file_name["Volume"]

# %% [markdown]
# ## 2.2.2 Inputting all features required
# ### EMA periods chosen are 2, 5, 10, 50
# ### Stochastic periods chosen are 5, 10, 20
# ### MACD periods chosen are 26, 12, 9 for fast, slow, signal respectively
# ### Force index chosen are 1, 2, 5

# %%
# Calculating ema
sti_df.reset_index(inplace=True) # Reset index for easier ema calculation
list_of_ema = [2, 5, 10, 50]
for i in list_of_ema:
    ema(sti_df,i,"Close")

# Calculating stochastic 
for i in [5, 10, 20]:
    stochastic(sti_df, period = i)

# Adding force index period 1 feature into data
force_index(sti_df) # Default for force index, period 1 has to be calculated first before calculating other periods

# Calcuation of force index for period 2 and 5 by using ema on force index period 1
ema(sti_df,2,"force_index_period_1",column_name="force_index")
ema(sti_df,5,"force_index_period_1",column_name="force_index")

# Calculating ema for 12 and 26 periods to calculate macd
ema(sti_df,12,"Close")
ema(sti_df,26,"Close")
macd(sti_df)

# %%
sti_df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  8725.000000  8725.000000  8725.000000  8725.000000  8.725000e+03
# mean   2350.624397  2362.311594  2337.971800  2350.047382  9.995847e+07
# std     749.055896   751.932317   745.681364   748.782332  1.248053e+08
# min     805.140015   809.869995   800.270020   805.039978  0.000000e+00
# 25%    1679.479980  1692.699951  1665.540039  1679.390015  0.000000e+00
# 50%    2301.800049  2311.699951  2287.699951  2300.699951  3.550700e+07
# 75%    3089.909912  3104.250000  3074.389893  3089.489990  1.888355e+08
# max    3899.290039  3906.159912  3852.689941  3875.770020  1.472752e+09
#
#        ema_period_2  ema_period_5  ema_period_10  ema_period_50  \
# count   8725.000000   8725.000000    8725.000000    8725.000000
# mean    2349.813500   2349.110505    2347.920837    2338.588962
# std      748.916973    749.422700     750.327256     757.377855
# min        0.000000      0.000000       0.000000       0.000000
# 25%     1678.598635   1677.239688    1680.211404    1687.430872
# 50%     2298.932281   2298.578020    2301.163008    2275.732235
# 75%     3090.475200   3092.223910    3092.907394    3100.544565
# max     3860.645022   3849.150933    3818.500405    3674.783315
#
#        high_period_5  ...  stochastic_period_20   close_diff  \
# count    8721.000000  ...           8706.000000  8724.000000
# mean     2374.882861  ...             55.430693     0.279085
# std       751.211894  ...             36.387188    25.179144
# min       856.429993  ...              0.000000  -190.369995
# 25%      1706.130005  ...             20.551913   -11.500000
# 50%      2320.899902  ...             60.791162     0.475098
# 75%      3116.320068  ...             91.148311    12.882599
# max      3875.770020  ...            100.000000   191.669922
#
#        force_index_period_1  force_index_2  force_index_5  ema_period_12  \
# count          8.724000e+03   8.725000e+03   8.725000e+03    8725.000000
# mean           2.088673e+07   2.109403e+07   2.096541e+07    2347.452828
# std            5.394314e+09   3.881464e+09   2.544677e+09     750.677996
# min           -8.988537e+10  -6.008900e+10  -3.994877e+10       0.000000
# 25%           -6.111394e+07  -2.880194e+07  -1.335211e+07    1681.223144
# 50%           -0.000000e+00   0.000000e+00   0.000000e+00    2300.605515
# 75%            2.158042e+08   2.299302e+08   2.083466e+08    3093.574105
# max            9.042893e+10   6.498969e+10   3.486305e+10    3806.921409
#
#        ema_period_26         macd  signal_of_macd_9  macd_histogram
# count    8725.000000  8725.000000       8725.000000     8725.000000
# mean     2344.168800     3.284029          3.266807        0.017222
# std       753.213382    47.657463         42.251529       19.708021
# min         0.000000  -221.245311       -183.551821     -673.234215
# 25%      1685.871761   -13.255192        -12.792038       -4.978693
# 50%      2293.480590     4.017638          4.255950       -0.085536
# 75%      3095.347488    21.098501         20.051119        4.875288
# max      3740.609670   898.894496        854.767125      688.559998
#
# [8 rows x 27 columns]

# %% [markdown]
# ## 2.2.3 Calculating change in features from previous day
# ### Traditionally trend or change in indicators from previous days are observed to predict trend in stocks
# ### Here, the change in indicators from previous day to current day are used as features
# ### Difference between the closing price and EMA of 5, 10, 50 are used to used as features too

# %%
# Calculating change of ema period 5, 10, 50
sti_df["ema_period_5_diff"] = sti_df["ema_period_5"].diff()
sti_df["ema_period_10_diff"] = sti_df["ema_period_10"].diff()
sti_df["ema_period_50_diff"] = sti_df["ema_period_50"].diff()

# %%
# Change in force index period 1, 2, 5
sti_df["force_index_2_diff"] = sti_df["force_index_2"].diff()	
sti_df["force_index_5_diff"] = sti_df["force_index_5"].diff()

# %%
# Calculate the change from previous to current macd, signal_of_macd, macd histogram as features
sti_df["macd_diff"] = sti_df["macd"].diff()
sti_df["signal_of_macd_9_diff"] = sti_df["signal_of_macd_9"].diff()
sti_df["macd_histogram_diff"] = sti_df["macd_histogram"].diff()

# %%
# Difference between "Close" and ema period 5, 10, 50 as features
sti_df["close_ema_5_diff"] = sti_df["Close"] - sti_df["ema_period_5"]
sti_df["close_ema_10_diff"] = sti_df["Close"] - sti_df["ema_period_10"]
sti_df["close_ema_50_diff"] = sti_df["Close"] - sti_df["ema_period_50"]

# %%
# Classification based on change in ema period of 5 days, 1 for positive change and 0 for negative change
sti_df.loc[sti_df['ema_period_5_diff'] > 0, ['Next_day_movement']] = 1
sti_df.loc[sti_df['ema_period_5_diff'] <= 0, ['Next_day_movement']] = 0

# Shifting the current day movement to previous day to put it as label
sti_df['Next_day_movement'] = sti_df['Next_day_movement'].shift(-1)

# Remove data that has no volume/ no trades and reset index
sti_df_clean = sti_df[sti_df["Volume"] > 0].reset_index().dropna() # Dropna is to remove current day record which have no next day movement

# %%
# Separating data after 2022 for validation after train test
sti_df_tt = sti_df_clean.loc[sti_df_clean["Date"] < '2022']
sti_df_validation = sti_df_clean.loc[sti_df_clean["Date"] > '2022']

# %% [markdown]
# # 3 Testing of different classification machine learning

# %% [markdown]
# ## 3.1 Testing of baseline model, logistic model

# %%
# Slice X and y for test, train
X = sti_df_tt[['ema_period_5_diff', 'stochastic_period_5', 'force_index_5', 'macd_diff', 'stochastic_period_10']]
y = sti_df_tt["Next_day_movement"]

# %%
# 80% of the data to be training set while 20% of the data to be test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 111)

# %%
# Scale and fit the train and test data sets
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Storing of metrics values
optimised_metrics_df = pd.DataFrame()

# %%
# Initialise classification model
clf_lr = LogisticRegression(random_state = 111)

# Testing logistic regression model
clf_lr.fit(X_train, y_train)
y_pred = clf_lr.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

# Plotting confusion matrix heatmap
fig, heatmap_cm = plt.subplots(figsize=(4,4))
sns.heatmap(cm, annot=True, fmt=".1f", ax=heatmap_cm, annot_kws={"fontsize":15})
heatmap_cm.set(xlabel="Predicted movement", ylabel="Actual movement")
heatmap_cm.set_title("Heatmap of logistic regression confusion matrix", fontsize=10)

# Store metrics values into dataframe
optimised_metrics_df["Regression forest"] = [accuracy_score(y_test, y_pred),
                                            precision_score(y_test, y_pred),
                                            log_loss(y_test, clf_lr.predict_proba(X_test)[:,1]),
                                            roc_auc_score(y_test, clf_lr.predict_proba(X_test)[:,1])]

# %% [markdown]
# ## 3.2 Optimising RF model

# %%
# Optimising random forest classifier using GridSearchCV
rf_param_grid = {'max_depth' : [1,2,3], 
               'criterion': ['gini','entropy'],
               'n_estimators': [250, 275, 300]
} 

clf_rf = RandomForestClassifier(random_state = 111) 
clf_rf_grid = GridSearchCV(clf_rf, rf_param_grid, cv=5, verbose=1)

# Fitting train data into unoptimised random forest model with parameters to be optimised
clf_rf_grid.fit(X_train,y_train) # Takes sometime to run
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=111),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 3],
#                          'n_estimators': [250, 275, 300]},
#              verbose=1)

# %%
# Showing what are the best parameters to use
clf_rf_grid.best_estimator_
# Out:
# RandomForestClassifier(max_depth=1, n_estimators=275, random_state=111)

# %%
# Testing optimised random forest model
clf_rf_optimised = clf_rf_grid.best_estimator_
clf_rf_optimised.fit(X_train, y_train)
y_pred = clf_rf_optimised.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

# Plotting confusion matrix heatmap
fig, heatmap_cm = plt.subplots(figsize=(4,4))
sns.heatmap(cm, annot=True, fmt=".1f", ax=heatmap_cm, annot_kws={"fontsize":15})
heatmap_cm.set(xlabel="Predicted movement", ylabel="Actual movement")
heatmap_cm.set_title("Heatmap of optimised random forest confusion matrix", fontsize=10)

# Store metrics values into dataframe
optimised_metrics_df["optimised random forest"] = [accuracy_score(y_test, y_pred),
                                                    precision_score(y_test, y_pred),
                                                    log_loss(y_test, clf_rf_optimised.predict_proba(X_test)[:,1]),
                                                    roc_auc_score(y_test, clf_rf_optimised.predict_proba(X_test)[:,1])]

# %% [markdown]
# ## 3.3 Optimising support vector classification (SVC) model

# %%
# Optimising SVC model hyperparameters
clf_svc = SVC(random_state = 111, probability=True)
svc_param_grid = {'C': [0.04, 0.05, 0.06], 
              'gamma': [0.05, 0.06, 0.07]}

clf_svc_grid = GridSearchCV(clf_svc, svc_param_grid, cv=5, verbose=1)

# Fitting train data into unoptimised SVC model with parameters to be optimised
clf_svc_grid.fit(X_train, y_train) # Take some time to run
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# GridSearchCV(cv=5, estimator=SVC(probability=True, random_state=111),
#              param_grid={'C': [0.04, 0.05, 0.06], 'gamma': [0.05, 0.06, 0.07]},
#              verbose=1)

# %%
# Showing what are the best parameters to use
clf_svc_grid.best_estimator_
# Out:
# SVC(C=0.05, gamma=0.06, probability=True, random_state=111)

# %%
# Testing of optimised SVC model
clf_svc_optimised = clf_svc_grid.best_estimator_
clf_svc_optimised.fit(X_train, y_train)
y_pred = clf_svc_optimised.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

# Plotting confusion matrix heatmap
fig, heatmap_cm = plt.subplots(figsize=(4,4))
sns.heatmap(cm, annot=True, fmt=".1f", ax=heatmap_cm, annot_kws={"fontsize":15})
heatmap_cm.set(xlabel="Predicted movement", ylabel="Actual movement")
heatmap_cm.set_title("Heatmap of optimised SVC confusion matrix", fontsize=10)

# Store metrics values into dataframe
optimised_metrics_df["optimised SVC"] = [accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        log_loss(y_test, clf_svc_optimised.predict_proba(X_test)[:,1]),
                                        roc_auc_score(y_test, clf_svc_optimised.predict_proba(X_test)[:,1])]

# %% [markdown]
# ## 3.4 Optimising XG booster model

# %%
# Optimising XG boost model hyperparameters
# Take some time to run
clf_xgb = xgb.XGBClassifier(objective='binary:logistic', random_state = 111)

xbg_param_grid =  {"learning_rate" : [0.07,0.08,0.09]
                , 'max_depth' : [30,40,50]
                , "eval_metric" : ["error"]
                , "gamma" : [6,7,8]
                , "early_stopping_rounds" : [10,20,40]
                }
                 
clf_xgb_grid = GridSearchCV(param_grid= xbg_param_grid , 
                              estimator= clf_xgb, 
                              cv= 5, verbose=1)

eval_set = [(X_train, y_train), (X_test, y_test)]

clf_xgb_grid.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=1)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [0]	validation_0-error:0.26428
# [1]	validation_0-error:0.25557
# [2]	validation_0-error:0.25169
# [3]	validation_0-error:0.25557
# [4]	validation_0-error:0.25557
# [5]	validation_0-error:0.25847
# [6]	validation_0-error:0.25557
# [7]	validation_0-error:0.26137
# [8]	validation_0-error:0.26041
# [9]	validation_0-error:0.25750
# [10]	validation_0-error:0.26041
# [11]	validation_0-error:0.25847
# [12]	validation_0-error:0.25750
# [0]	validation_0-error:0.28267
# [1]	validation_0-error:0.27590
# [2]	validation_0-error:0.26137
# [3]	validation_0-error:0.26718
# [4]	validation_0-error:0.26718
# [5]	validation_0-error:0.26137
# [6]	validation_0-error:0.26428
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25653
# [9]	validation_0-error:0.25653
# [10]	validation_0-error:0.25557
# [11]	validation_0-error:0.25847
# [12]	validation_0-error:0.26234
# [13]	validation_0-error:0.26137
# [14]	validation_0-error:0.25944
# [15]	validation_0-error:0.26137
# [16]	validation_0-error:0.25460
# [17]	validation_0-error:0.25557
# [18]	validation_0-error:0.25460
# [19]	validation_0-error:0.25460
# [20]	validation_0-error:0.25460
# [21]	validation_0-error:0.25460
# [22]	validation_0-error:0.25847
# [23]	validation_0-error:0.25750
# [24]	validation_0-error:0.25653
# [25]	validation_0-error:0.25750
# [0]	validation_0-error:0.28558
# [1]	validation_0-error:0.27106
# [2]	validation_0-error:0.26137
# [3]	validation_0-error:0.26041
# [4]	validation_0-error:0.25460
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.25653
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25363
# [9]	validation_0-error:0.25847
# [10]	validation_0-error:0.25750
# [11]	validation_0-error:0.26234
# [12]	validation_0-error:0.26331
# [13]	validation_0-error:0.26137
# [14]	validation_0-error:0.25653
# [15]	validation_0-error:0.25557
# [16]	validation_0-error:0.25847
# [17]	validation_0-error:0.25653
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.26137
# [2]	validation_0-error:0.25169
# [3]	validation_0-error:0.25169
# [4]	validation_0-error:0.25169
# [5]	validation_0-error:0.24976
# [6]	validation_0-error:0.25169
# [7]	validation_0-error:0.24685
# [8]	validation_0-error:0.24879
# [9]	validation_0-error:0.24879
# [10]	validation_0-error:0.25073
# [11]	validation_0-error:0.25363
# [12]	validation_0-error:0.25460
# [13]	validation_0-error:0.25169
# [14]	validation_0-error:0.25363
# [15]	validation_0-error:0.25169
# [16]	validation_0-error:0.25266
# [0]	validation_0-error:0.26137
# [1]	validation_0-error:0.26331
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.26041
# [4]	validation_0-error:0.25847
# [5]	validation_0-error:0.25460
# [6]	validation_0-error:0.25557
# [7]	validation_0-error:0.25363
# [8]	validation_0-error:0.24976
# [9]	validation_0-error:0.24976
# [10]	validation_0-error:0.25073
# [11]	validation_0-error:0.25460
# [12]	validation_0-error:0.24879
# [13]	validation_0-error:0.24879
# [14]	validation_0-error:0.25266
# [15]	validation_0-error:0.24976
# [16]	validation_0-error:0.25266
# [17]	validation_0-error:0.25266
# [18]	validation_0-error:0.25169
# [19]	validation_0-error:0.25169
# [20]	validation_0-error:0.25363
# [21]	validation_0-error:0.25266
# [0]	validation_0-error:0.26428
# [1]	validation_0-error:0.25557
# [2]	validation_0-error:0.25169
# [3]	validation_0-error:0.25557
# [4]	validation_0-error:0.25557
# [5]	validation_0-error:0.25847
# [6]	validation_0-error:0.25557
# [7]	validation_0-error:0.26137
# [8]	validation_0-error:0.26041
# [9]	validation_0-error:0.25750
# [10]	validation_0-error:0.26041
# [11]	validation_0-error:0.25847
# [0]	validation_0-error:0.28267
# [1]	validation_0-error:0.27590
# [2]	validation_0-error:0.26137
# [3]	validation_0-error:0.26718
# [4]	validation_0-error:0.26718
# [5]	validation_0-error:0.26137
# [6]	validation_0-error:0.26428
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25653
# [9]	validation_0-error:0.25653
# [10]	validation_0-error:0.25557
# [11]	validation_0-error:0.25847
# [12]	validation_0-error:0.26234
# [13]	validation_0-error:0.26137
# [14]	validation_0-error:0.25944
# [15]	validation_0-error:0.26137
# [16]	validation_0-error:0.25460
# [17]	validation_0-error:0.25557
# [18]	validation_0-error:0.25460
# [19]	validation_0-error:0.25460
# [20]	validation_0-error:0.25460
# [21]	validation_0-error:0.25460
# [22]	validation_0-error:0.25847
# [23]	validation_0-error:0.25750
# [24]	validation_0-error:0.25653
# [25]	validation_0-error:0.25750
# [0]	validation_0-error:0.28558
# [1]	validation_0-error:0.27106
# [2]	validation_0-error:0.26137
# [3]	validation_0-error:0.26041
# [4]	validation_0-error:0.25460
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.25653
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25363
# [9]	validation_0-error:0.25847
# [10]	validation_0-error:0.25750
# [11]	validation_0-error:0.26234
# [12]	validation_0-error:0.26331
# [13]	validation_0-error:0.26137
# [14]	validation_0-error:0.25653
# [15]	validation_0-error:0.25557
# [16]	validation_0-error:0.25847
# [17]	validation_0-error:0.25653
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.26137
# [2]	validation_0-error:0.25169
# [3]	validation_0-error:0.25169
# [4]	validation_0-error:0.25169
# [5]	validation_0-error:0.24976
# [6]	validation_0-error:0.25169
# [7]	validation_0-error:0.24685
# [8]	validation_0-error:0.24879
# [9]	validation_0-error:0.24879
# [10]	validation_0-error:0.25073
# [11]	validation_0-error:0.25363
# [12]	validation_0-error:0.25460
# [13]	validation_0-error:0.25169
# [14]	validation_0-error:0.25363
# [15]	validation_0-error:0.25169
# [16]	validation_0-error:0.25266
# [0]	validation_0-error:0.26137
# [1]	validation_0-error:0.26331
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.26041
# [4]	validation_0-error:0.25847
# [5]	validation_0-error:0.25460
# [6]	validation_0-error:0.25557
# [7]	validation_0-error:0.25363
# [8]	validation_0-error:0.24976
# [9]	validation_0-error:0.24976
# [10]	validation_0-error:0.25073
# [11]	validation_0-error:0.25460
# [12]	validation_0-error:0.24879
# [13]	validation_0-error:0.24879
# [14]	validation_0-error:0.25266
# [15]	validation_0-error:0.24976
# [16]	validation_0-error:0.25266
# [17]	validation_0-error:0.25266
# [18]	validation_0-error:0.25169
# [19]	validation_0-error:0.25169
# [20]	validation_0-error:0.25363
# [21]	validation_0-error:0.25266
# [0]	validation_0-error:0.26428
# [1]	validation_0-error:0.25557
# [2]	validation_0-error:0.25169
# [3]	validation_0-error:0.25557
# [4]	validation_0-error:0.25557
# [5]	validation_0-error:0.25847
# [6]	validation_0-error:0.25557
# [7]	validation_0-error:0.26137
# [8]	validation_0-error:0.26041
# [9]	validation_0-error:0.25750
# [10]	validation_0-error:0.26041
# [11]	validation_0-error:0.25847
# [0]	validation_0-error:0.28267
# [1]	validation_0-error:0.27590
# [2]	validation_0-error:0.26137
# [3]	validation_0-error:0.26718
# [4]	validation_0-error:0.26718
# [5]	validation_0-error:0.26137
# [6]	validation_0-error:0.26428
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25653
# [9]	validation_0-error:0.25653
# [10]	validation_0-error:0.25557
# [11]	validation_0-error:0.25847
# [12]	validation_0-error:0.26234
# [13]	validation_0-error:0.26137
# [14]	validation_0-error:0.25944
# [15]	validation_0-error:0.26137
# [16]	validation_0-error:0.25460
# [17]	validation_0-error:0.25557
# [18]	validation_0-error:0.25460
# [19]	validation_0-error:0.25460
# [20]	validation_0-error:0.25460
# [21]	validation_0-error:0.25460
# [22]	validation_0-error:0.25847
# [23]	validation_0-error:0.25750
# [24]	validation_0-error:0.25653
# [25]	validation_0-error:0.25750
# [0]	validation_0-error:0.28558
# [1]	validation_0-error:0.27106
# [2]	validation_0-error:0.26137
# [3]	validation_0-error:0.26041
# [4]	validation_0-error:0.25460
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.25653
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25363
# [9]	validation_0-error:0.25847
# [10]	validation_0-error:0.25750
# [11]	validation_0-error:0.26234
# [12]	validation_0-error:0.26331
# [13]	validation_0-error:0.26137
# [14]	validation_0-error:0.25653
# [15]	validation_0-error:0.25557
# [16]	validation_0-error:0.25847
# [17]	validation_0-error:0.25653
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.26137
# [2]	validation_0-error:0.25169
# [3]	validation_0-error:0.25169
# [4]	validation_0-error:0.25169
# [5]	validation_0-error:0.24976
# [6]	validation_0-error:0.25169
# [7]	validation_0-error:0.24685
# [8]	validation_0-error:0.24879
# [9]	validation_0-error:0.24879
# [10]	validation_0-error:0.25073
# [11]	validation_0-error:0.25363
# [12]	validation_0-error:0.25460
# [13]	validation_0-error:0.25169
# [14]	validation_0-error:0.25363
# [15]	validation_0-error:0.25169
# [16]	validation_0-error:0.25266
# [0]	validation_0-error:0.26137
# [1]	validation_0-error:0.26331
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.26041
# [4]	validation_0-error:0.25847
# [5]	validation_0-error:0.25460
# [6]	validation_0-error:0.25557
# [7]	validation_0-error:0.25363
# [8]	validation_0-error:0.24976
# [9]	validation_0-error:0.24976
# [10]	validation_0-error:0.25073
# [11]	validation_0-error:0.25460
# [12]	validation_0-error:0.24879
# [13]	validation_0-error:0.24879
# [14]	validation_0-error:0.25266
# [15]	validation_0-error:0.24976
# [16]	validation_0-error:0.25266
# [17]	validation_0-error:0.25266
# [18]	validation_0-error:0.25169
# [19]	validation_0-error:0.25169
# [20]	validation_0-error:0.25363
# [21]	validation_0-error:0.25266
# [0]	validation_0-error:0.26428
# [1]	validation_0-error:0.25557
# [2]	validation_0-error:0.26234
# [3]	validation_0-error:0.26331
# [4]	validation_0-error:0.26525
# [5]	validation_0-error:0.26525
# [6]	validation_0-error:0.26718
# [7]	validation_0-error:0.26621
# [8]	validation_0-error:0.26621
# [9]	validation_0-error:0.26815
# [10]	validation_0-error:0.26621
# [0]	validation_0-error:0.28267
# [1]	validation_0-error:0.27590
# [2]	validation_0-error:0.26621
# [3]	validation_0-error:0.26912
# [4]	validation_0-error:0.26525
# [5]	validation_0-error:0.26621
# [6]	validation_0-error:0.26041
# [7]	validation_0-error:0.25557
# [8]	validation_0-error:0.25750
# [9]	validation_0-error:0.25847
# [10]	validation_0-error:0.25750
# [11]	validation_0-error:0.25944
# [12]	validation_0-error:0.25944
# [13]	validation_0-error:0.26428
# [14]	validation_0-error:0.26621
# [15]	validation_0-error:0.26041
# [16]	validation_0-error:0.25944
# [0]	validation_0-error:0.28558
# [1]	validation_0-error:0.27009
# [2]	validation_0-error:0.26912
# [3]	validation_0-error:0.26621
# [4]	validation_0-error:0.25847
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.25944
# [7]	validation_0-error:0.25750
# [8]	validation_0-error:0.25557
# [9]	validation_0-error:0.25653
# [10]	validation_0-error:0.25750
# [11]	validation_0-error:0.25847
# [12]	validation_0-error:0.24879
# [13]	validation_0-error:0.25363
# [14]	validation_0-error:0.25460
# [15]	validation_0-error:0.25363
# [16]	validation_0-error:0.24782
# [17]	validation_0-error:0.24879
# [18]	validation_0-error:0.24879
# [19]	validation_0-error:0.24685
# [20]	validation_0-error:0.24685
# [21]	validation_0-error:0.24685
# [22]	validation_0-error:0.24976
# [23]	validation_0-error:0.24879
# [24]	validation_0-error:0.24685
# [25]	validation_0-error:0.24685
# [26]	validation_0-error:0.24589
# [27]	validation_0-error:0.24685
# [28]	validation_0-error:0.24879
# [29]	validation_0-error:0.24879
# [30]	validation_0-error:0.25073
# [31]	validation_0-error:0.24976
# [32]	validation_0-error:0.25169
# [33]	validation_0-error:0.25557
# [34]	validation_0-error:0.25557
# [35]	validation_0-error:0.25557
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.26912
# [2]	validation_0-error:0.25363
# [3]	validation_0-error:0.24976
# [4]	validation_0-error:0.24879
# [5]	validation_0-error:0.25073
# [6]	validation_0-error:0.25266
# [7]	validation_0-error:0.25073
# [8]	validation_0-error:0.24685
# [9]	validation_0-error:0.24589
# [10]	validation_0-error:0.24685
# [11]	validation_0-error:0.24685
# [12]	validation_0-error:0.25169
# [13]	validation_0-error:0.25169
# [14]	validation_0-error:0.24879
# [15]	validation_0-error:0.25073
# [16]	validation_0-error:0.24976
# [17]	validation_0-error:0.25073
# [18]	validation_0-error:0.25073
# [0]	validation_0-error:0.26137
# [1]	validation_0-error:0.26331
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.25750
# [4]	validation_0-error:0.25557
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.24879
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25266
# [9]	validation_0-error:0.25363
# [10]	validation_0-error:0.25363
# [11]	validation_0-error:0.25363
# [12]	validation_0-error:0.25266
# [13]	validation_0-error:0.24976
# [14]	validation_0-error:0.24976
# [15]	validation_0-error:0.24782
# [16]	validation_0-error:0.24782
# [17]	validation_0-error:0.24879
# [18]	validation_0-error:0.24782
# [19]	validation_0-error:0.24685
# [20]	validation_0-error:0.25363
# [21]	validation_0-error:0.25266
# [22]	validation_0-error:0.25363
# [23]	validation_0-error:0.25363
# [24]	validation_0-error:0.25363
# [25]	validation_0-error:0.25363
# [26]	validation_0-error:0.25363
# [27]	validation_0-error:0.25363
# [28]	validation_0-error:0.25169
# [0]	validation_0-error:0.26428
# [1]	validation_0-error:0.25557
# [2]	validation_0-error:0.26234
# [3]	validation_0-error:0.26331
# [4]	validation_0-error:0.26525
# [5]	validation_0-error:0.26525
# [6]	validation_0-error:0.26718
# [7]	validation_0-error:0.26621
# [8]	validation_0-error:0.26621
# [9]	validation_0-error:0.26815
# [10]	validation_0-error:0.26621
# [0]	validation_0-error:0.28267
# [1]	validation_0-error:0.27590
# [2]	validation_0-error:0.26621
# [3]	validation_0-error:0.26912
# [4]	validation_0-error:0.26525
# [5]	validation_0-error:0.26621
# [6]	validation_0-error:0.26041
# [7]	validation_0-error:0.25557
# [8]	validation_0-error:0.25750
# [9]	validation_0-error:0.25847
# [10]	validation_0-error:0.25750
# [11]	validation_0-error:0.25944
# [12]	validation_0-error:0.25944
# [13]	validation_0-error:0.26428
# [14]	validation_0-error:0.26621
# [15]	validation_0-error:0.26041
# [16]	validation_0-error:0.25944
# [0]	validation_0-error:0.28558
# [1]	validation_0-error:0.27009
# [2]	validation_0-error:0.26912
# [3]	validation_0-error:0.26621
# [4]	validation_0-error:0.25847
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.25944
# [7]	validation_0-error:0.25750
# [8]	validation_0-error:0.25557
# [9]	validation_0-error:0.25653
# [10]	validation_0-error:0.25750
# [11]	validation_0-error:0.25847
# [12]	validation_0-error:0.24879
# [13]	validation_0-error:0.25363
# [14]	validation_0-error:0.25460
# [15]	validation_0-error:0.25363
# [16]	validation_0-error:0.24782
# [17]	validation_0-error:0.24879
# [18]	validation_0-error:0.24879
# [19]	validation_0-error:0.24685
# [20]	validation_0-error:0.24685
# [21]	validation_0-error:0.24685
# [22]	validation_0-error:0.24976
# [23]	validation_0-error:0.24879
# [24]	validation_0-error:0.24685
# [25]	validation_0-error:0.24685
# [26]	validation_0-error:0.24589
# [27]	validation_0-error:0.24685
# [28]	validation_0-error:0.24879
# [29]	validation_0-error:0.24879
# [30]	validation_0-error:0.25073
# [31]	validation_0-error:0.24976
# [32]	validation_0-error:0.25266
# [33]	validation_0-error:0.25169
# [34]	validation_0-error:0.25460
# [35]	validation_0-error:0.25266
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.26912
# [2]	validation_0-error:0.25363
# [3]	validation_0-error:0.24976
# [4]	validation_0-error:0.24879
# [5]	validation_0-error:0.25073
# [6]	validation_0-error:0.25266
# [7]	validation_0-error:0.25073
# [8]	validation_0-error:0.24685
# [9]	validation_0-error:0.24589
# [10]	validation_0-error:0.24685
# [11]	validation_0-error:0.24685
# [12]	validation_0-error:0.25169
# [13]	validation_0-error:0.25169
# [14]	validation_0-error:0.24879
# [15]	validation_0-error:0.25073
# [16]	validation_0-error:0.24976
# [17]	validation_0-error:0.25073
# [18]	validation_0-error:0.25073
# [0]	validation_0-error:0.26137
# [1]	validation_0-error:0.26331
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.25750
# [4]	validation_0-error:0.25557
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.24879
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25266
# [9]	validation_0-error:0.25363
# [10]	validation_0-error:0.25363
# [11]	validation_0-error:0.25363
# [12]	validation_0-error:0.25266
# [13]	validation_0-error:0.24976
# [14]	validation_0-error:0.24976
# [15]	validation_0-error:0.24782
# [16]	validation_0-error:0.24782
# [17]	validation_0-error:0.24879
# [18]	validation_0-error:0.24782
# [19]	validation_0-error:0.24685
# [20]	validation_0-error:0.25363
# [21]	validation_0-error:0.25266
# [22]	validation_0-error:0.25363
# [23]	validation_0-error:0.25363
# [24]	validation_0-error:0.25363
# [25]	validation_0-error:0.25363
# [26]	validation_0-error:0.25363
# [27]	validation_0-error:0.25363
# [28]	validation_0-error:0.25169
# [0]	validation_0-error:0.26428
# [1]	validation_0-error:0.25557
# [2]	validation_0-error:0.26234
# [3]	validation_0-error:0.26331
# [4]	validation_0-error:0.26525
# [5]	validation_0-error:0.26525
# [6]	validation_0-error:0.26718
# [7]	validation_0-error:0.26621
# [8]	validation_0-error:0.26621
# [9]	validation_0-error:0.26815
# [10]	validation_0-error:0.26621
# [0]	validation_0-error:0.28267
# [1]	validation_0-error:0.27590
# [2]	validation_0-error:0.26621
# [3]	validation_0-error:0.26912
# [4]	validation_0-error:0.26525
# [5]	validation_0-error:0.26621
# [6]	validation_0-error:0.26041
# [7]	validation_0-error:0.25557
# [8]	validation_0-error:0.25750
# [9]	validation_0-error:0.25847
# [10]	validation_0-error:0.25750
# [11]	validation_0-error:0.25944
# [12]	validation_0-error:0.25944
# [13]	validation_0-error:0.26428
# [14]	validation_0-error:0.26621
# [15]	validation_0-error:0.26041
# [16]	validation_0-error:0.25944
# [0]	validation_0-error:0.28558
# [1]	validation_0-error:0.27009
# [2]	validation_0-error:0.26912
# [3]	validation_0-error:0.26621
# [4]	validation_0-error:0.25847
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.25944
# [7]	validation_0-error:0.25750
# [8]	validation_0-error:0.25557
# [9]	validation_0-error:0.25653
# [10]	validation_0-error:0.25750
# [11]	validation_0-error:0.25847
# [12]	validation_0-error:0.24879
# [13]	validation_0-error:0.25363
# [14]	validation_0-error:0.25460
# [15]	validation_0-error:0.25363
# [16]	validation_0-error:0.24782
# [17]	validation_0-error:0.24879
# [18]	validation_0-error:0.24879
# [19]	validation_0-error:0.24685
# [20]	validation_0-error:0.24685
# [21]	validation_0-error:0.24685
# [22]	validation_0-error:0.24976
# [23]	validation_0-error:0.24879
# [24]	validation_0-error:0.24685
# [25]	validation_0-error:0.24685
# [26]	validation_0-error:0.24589
# [27]	validation_0-error:0.24685
# [28]	validation_0-error:0.24879
# [29]	validation_0-error:0.24879
# [30]	validation_0-error:0.25073
# [31]	validation_0-error:0.24976
# [32]	validation_0-error:0.25266
# [33]	validation_0-error:0.25169
# [34]	validation_0-error:0.25460
# [35]	validation_0-error:0.25266
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.26912
# [2]	validation_0-error:0.25363
# [3]	validation_0-error:0.24976
# [4]	validation_0-error:0.24879
# [5]	validation_0-error:0.25073
# [6]	validation_0-error:0.25266
# [7]	validation_0-error:0.25073
# [8]	validation_0-error:0.24685
# [9]	validation_0-error:0.24589
# [10]	validation_0-error:0.24685
# [11]	validation_0-error:0.24685
# [12]	validation_0-error:0.25169
# [13]	validation_0-error:0.25169
# [14]	validation_0-error:0.24879
# [15]	validation_0-error:0.25073
# [16]	validation_0-error:0.24976
# [17]	validation_0-error:0.25073
# [18]	validation_0-error:0.25073
# [0]	validation_0-error:0.26137
# [1]	validation_0-error:0.26331
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.25750
# [4]	validation_0-error:0.25557
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.24879
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25266
# [9]	validation_0-error:0.25363
# [10]	validation_0-error:0.25363
# [11]	validation_0-error:0.25363
# [12]	validation_0-error:0.25266
# [13]	validation_0-error:0.24976
# [14]	validation_0-error:0.24976
# [15]	validation_0-error:0.24782
# [16]	validation_0-error:0.24782
# [17]	validation_0-error:0.24879
# [18]	validation_0-error:0.24782
# [19]	validation_0-error:0.24685
# [20]	validation_0-error:0.25363
# [21]	validation_0-error:0.25266
# [22]	validation_0-error:0.25363
# [23]	validation_0-error:0.25363
# [24]	validation_0-error:0.25363
# [25]	validation_0-error:0.25363
# [26]	validation_0-error:0.25363
# [27]	validation_0-error:0.25363
# [28]	validation_0-error:0.25169
# [0]	validation_0-error:0.26428
# [1]	validation_0-error:0.26428
# [2]	validation_0-error:0.25847
# [3]	validation_0-error:0.26137
# [4]	validation_0-error:0.26331
# [5]	validation_0-error:0.26137
# [6]	validation_0-error:0.25363
# [7]	validation_0-error:0.25944
# [8]	validation_0-error:0.25750
# [9]	validation_0-error:0.25653
# [10]	validation_0-error:0.26234
# [11]	validation_0-error:0.25653
# [12]	validation_0-error:0.25750
# [13]	validation_0-error:0.25557
# [14]	validation_0-error:0.25750
# [15]	validation_0-error:0.26525
# [16]	validation_0-error:0.26234
# [0]	validation_0-error:0.28267
# [1]	validation_0-error:0.27590
# [2]	validation_0-error:0.27106
# [3]	validation_0-error:0.27202
# [4]	validation_0-error:0.26525
# [5]	validation_0-error:0.26428
# [6]	validation_0-error:0.26428
# [7]	validation_0-error:0.26331
# [8]	validation_0-error:0.26234
# [9]	validation_0-error:0.26041
# [10]	validation_0-error:0.26041
# [11]	validation_0-error:0.26331
# [12]	validation_0-error:0.26428
# [13]	validation_0-error:0.26234
# [14]	validation_0-error:0.26428
# [15]	validation_0-error:0.26718
# [16]	validation_0-error:0.26815
# [17]	validation_0-error:0.26718
# [18]	validation_0-error:0.26525
# [0]	validation_0-error:0.28558
# [1]	validation_0-error:0.25460
# [2]	validation_0-error:0.26137
# [3]	validation_0-error:0.25653
# [4]	validation_0-error:0.25557
# [5]	validation_0-error:0.24589
# [6]	validation_0-error:0.24492
# [7]	validation_0-error:0.24685
# [8]	validation_0-error:0.24589
# [9]	validation_0-error:0.24976
# [10]	validation_0-error:0.24976
# [11]	validation_0-error:0.25169
# [12]	validation_0-error:0.24976
# [13]	validation_0-error:0.25653
# [14]	validation_0-error:0.25460
# [15]	validation_0-error:0.25460
# [16]	validation_0-error:0.24976
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.25073
# [2]	validation_0-error:0.25944
# [3]	validation_0-error:0.24782
# [4]	validation_0-error:0.24589
# [5]	validation_0-error:0.24395
# [6]	validation_0-error:0.24976
# [7]	validation_0-error:0.24879
# [8]	validation_0-error:0.24782
# [9]	validation_0-error:0.24976
# [10]	validation_0-error:0.25266
# [11]	validation_0-error:0.25169
# [12]	validation_0-error:0.25363
# [13]	validation_0-error:0.25653
# [14]	validation_0-error:0.25073
# [0]	validation_0-error:0.26137
# [1]	validation_0-error:0.26428
# [2]	validation_0-error:0.25363
# [3]	validation_0-error:0.25750
# [4]	validation_0-error:0.25653
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.24976
# [7]	validation_0-error:0.25363
# [8]	validation_0-error:0.25653
# [9]	validation_0-error:0.25266
# [10]	validation_0-error:0.25557
# [11]	validation_0-error:0.25653
# [12]	validation_0-error:0.25847
# [13]	validation_0-error:0.26428
# [14]	validation_0-error:0.26428
# [15]	validation_0-error:0.26428
# [0]	validation_0-error:0.26428
# [1]	validation_0-error:0.26428
# [2]	validation_0-error:0.25847
# [3]	validation_0-error:0.26137
# [4]	validation_0-error:0.26331
# [5]	validation_0-error:0.26137
# [6]	validation_0-error:0.25363
# [7]	validation_0-error:0.25944
# [8]	validation_0-error:0.25750
# [9]	validation_0-error:0.25653
# [10]	validation_0-error:0.26234
# [11]	validation_0-error:0.25653
# [12]	validation_0-error:0.25750
# [13]	validation_0-error:0.25557
# [14]	validation_0-error:0.25750
# [15]	validation_0-error:0.26525
# [16]	validation_0-error:0.26234
# [0]	validation_0-error:0.28267
# [1]	validation_0-error:0.27590
# [2]	validation_0-error:0.27106
# [3]	validation_0-error:0.27202
# [4]	validation_0-error:0.26525
# [5]	validation_0-error:0.26428
# [6]	validation_0-error:0.26428
# [7]	validation_0-error:0.26331
# [8]	validation_0-error:0.26234
# [9]	validation_0-error:0.26041
# [10]	validation_0-error:0.26041
# [11]	validation_0-error:0.26331
# [12]	validation_0-error:0.26428
# [13]	validation_0-error:0.26234
# [14]	validation_0-error:0.26428
# [15]	validation_0-error:0.26718
# [16]	validation_0-error:0.26815
# [17]	validation_0-error:0.26718
# [18]	validation_0-error:0.26525
# [19]	validation_0-error:0.26331
# [0]	validation_0-error:0.28558
# [1]	validation_0-error:0.25460
# [2]	validation_0-error:0.26137
# [3]	validation_0-error:0.25653
# [4]	validation_0-error:0.25557
# [5]	validation_0-error:0.24589
# [6]	validation_0-error:0.24492
# [7]	validation_0-error:0.24685
# [8]	validation_0-error:0.24589
# [9]	validation_0-error:0.24976
# [10]	validation_0-error:0.24976
# [11]	validation_0-error:0.25169
# [12]	validation_0-error:0.24976
# [13]	validation_0-error:0.25653
# [14]	validation_0-error:0.25460
# [15]	validation_0-error:0.25460
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.25073
# [2]	validation_0-error:0.25944
# [3]	validation_0-error:0.24782
# [4]	validation_0-error:0.24589
# [5]	validation_0-error:0.24395
# [6]	validation_0-error:0.24976
# [7]	validation_0-error:0.24879
# [8]	validation_0-error:0.24782
# [9]	validation_0-error:0.24976
# [10]	validation_0-error:0.25266
# [11]	validation_0-error:0.25169
# [12]	validation_0-error:0.25363
# [13]	validation_0-error:0.25653
# [14]	validation_0-error:0.25073
# [0]	validation_0-error:0.26137
# [1]	validation_0-error:0.26428
# [2]	validation_0-error:0.25363
# [3]	validation_0-error:0.25750
# [4]	validation_0-error:0.25653
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.24976
# [7]	validation_0-error:0.25363
# [8]	validation_0-error:0.25653
# [9]	validation_0-error:0.25266
# [10]	validation_0-error:0.25557
# [11]	validation_0-error:0.25653
# [12]	validation_0-error:0.25847
# [13]	validation_0-error:0.26428
# [14]	validation_0-error:0.26428
# [15]	validation_0-error:0.26428
# [0]	validation_0-error:0.26428
# [1]	validation_0-error:0.26428
# [2]	validation_0-error:0.25847
# [3]	validation_0-error:0.26137
# [4]	validation_0-error:0.26331
# [5]	validation_0-error:0.26137
# [6]	validation_0-error:0.25363
# [7]	validation_0-error:0.25944
# [8]	validation_0-error:0.25750
# [9]	validation_0-error:0.25653
# [10]	validation_0-error:0.26234
# [11]	validation_0-error:0.25653
# [12]	validation_0-error:0.25750
# [13]	validation_0-error:0.25557
# [14]	validation_0-error:0.25750
# [15]	validation_0-error:0.26525
# [16]	validation_0-error:0.26234
# [0]	validation_0-error:0.28267
# [1]	validation_0-error:0.27590
# [2]	validation_0-error:0.27106
# [3]	validation_0-error:0.27202
# [4]	validation_0-error:0.26525
# [5]	validation_0-error:0.26428
# [6]	validation_0-error:0.26428
# [7]	validation_0-error:0.26331
# [8]	validation_0-error:0.26234
# [9]	validation_0-error:0.26041
# [10]	validation_0-error:0.26041
# [11]	validation_0-error:0.26331
# [12]	validation_0-error:0.26428
# [13]	validation_0-error:0.26234
# [14]	validation_0-error:0.26428
# [15]	validation_0-error:0.26718
# [16]	validation_0-error:0.26815
# [17]	validation_0-error:0.26718
# [18]	validation_0-error:0.26525
# [19]	validation_0-error:0.26331
# [0]	validation_0-error:0.28558
# [1]	validation_0-error:0.25460
# [2]	validation_0-error:0.26137
# [3]	validation_0-error:0.25653
# [4]	validation_0-error:0.25557
# [5]	validation_0-error:0.24589
# [6]	validation_0-error:0.24492
# [7]	validation_0-error:0.24685
# [8]	validation_0-error:0.24589
# [9]	validation_0-error:0.24976
# [10]	validation_0-error:0.24976
# [11]	validation_0-error:0.25169
# [12]	validation_0-error:0.24976
# [13]	validation_0-error:0.25653
# [14]	validation_0-error:0.25460
# [15]	validation_0-error:0.25460
# [16]	validation_0-error:0.24976
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.25073
# [2]	validation_0-error:0.25944
# [3]	validation_0-error:0.24782
# [4]	validation_0-error:0.24589
# [5]	validation_0-error:0.24395
# [6]	validation_0-error:0.24976
# [7]	validation_0-error:0.24879
# [8]	validation_0-error:0.24782
# [9]	validation_0-error:0.24976
# [10]	validation_0-error:0.25266
# [11]	validation_0-error:0.25169
# [12]	validation_0-error:0.25363
# [13]	validation_0-error:0.25653
# [14]	validation_0-error:0.25073
# [15]	validation_0-error:0.25073
# [0]	validation_0-error:0.26137
# [1]	validation_0-error:0.26428
# [2]	validation_0-error:0.25363
# [3]	validation_0-error:0.25750
# [4]	validation_0-error:0.25653
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.24976
# [7]	validation_0-error:0.25363
# [8]	validation_0-error:0.25653
# [9]	validation_0-error:0.25266
# [10]	validation_0-error:0.25557
# [11]	validation_0-error:0.25653
# [12]	validation_0-error:0.25847
# [13]	validation_0-error:0.26428
# [14]	validation_0-error:0.26428
# [15]	validation_0-error:0.26428
# [16]	validation_0-error:0.26041
# [0]	validation_0-error:0.25363
# [1]	validation_0-error:0.24879
# [2]	validation_0-error:0.24685
# [3]	validation_0-error:0.24685
# [4]	validation_0-error:0.25169
# [5]	validation_0-error:0.25266
# [6]	validation_0-error:0.24976
# [7]	validation_0-error:0.25169
# [8]	validation_0-error:0.24976
# [9]	validation_0-error:0.25169
# [10]	validation_0-error:0.25169
# [11]	validation_0-error:0.24976
# [0]	validation_0-error:0.27686
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.27299
# [3]	validation_0-error:0.27106
# [4]	validation_0-error:0.26234
# [5]	validation_0-error:0.26331
# [6]	validation_0-error:0.25847
# [7]	validation_0-error:0.25750
# [8]	validation_0-error:0.25653
# [9]	validation_0-error:0.26137
# [10]	validation_0-error:0.25847
# [11]	validation_0-error:0.25750
# [12]	validation_0-error:0.26041
# [13]	validation_0-error:0.26137
# [14]	validation_0-error:0.25750
# [15]	validation_0-error:0.25557
# [16]	validation_0-error:0.25557
# [17]	validation_0-error:0.25847
# [18]	validation_0-error:0.25847
# [19]	validation_0-error:0.25847
# [20]	validation_0-error:0.25944
# [21]	validation_0-error:0.25847
# [22]	validation_0-error:0.25847
# [23]	validation_0-error:0.25944
# [24]	validation_0-error:0.25944
# [0]	validation_0-error:0.26912
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.25073
# [4]	validation_0-error:0.25169
# [5]	validation_0-error:0.24976
# [6]	validation_0-error:0.25266
# [7]	validation_0-error:0.24976
# [8]	validation_0-error:0.25073
# [9]	validation_0-error:0.25169
# [10]	validation_0-error:0.25266
# [11]	validation_0-error:0.24976
# [12]	validation_0-error:0.24492
# [13]	validation_0-error:0.24976
# [14]	validation_0-error:0.24879
# [15]	validation_0-error:0.24976
# [16]	validation_0-error:0.24976
# [17]	validation_0-error:0.24782
# [18]	validation_0-error:0.24395
# [19]	validation_0-error:0.24298
# [20]	validation_0-error:0.24395
# [21]	validation_0-error:0.24782
# [22]	validation_0-error:0.24589
# [23]	validation_0-error:0.24395
# [24]	validation_0-error:0.24395
# [25]	validation_0-error:0.24395
# [26]	validation_0-error:0.24492
# [27]	validation_0-error:0.24395
# [28]	validation_0-error:0.24976
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.24976
# [2]	validation_0-error:0.25653
# [3]	validation_0-error:0.25847
# [4]	validation_0-error:0.25847
# [5]	validation_0-error:0.25363
# [6]	validation_0-error:0.25363
# [7]	validation_0-error:0.25363
# [8]	validation_0-error:0.25266
# [9]	validation_0-error:0.25363
# [10]	validation_0-error:0.25460
# [11]	validation_0-error:0.25460
# [0]	validation_0-error:0.26815
# [1]	validation_0-error:0.25944
# [2]	validation_0-error:0.25460
# [3]	validation_0-error:0.25847
# [4]	validation_0-error:0.25847
# [5]	validation_0-error:0.25653
# [6]	validation_0-error:0.25460
# [7]	validation_0-error:0.25460
# [8]	validation_0-error:0.24782
# [9]	validation_0-error:0.24879
# [10]	validation_0-error:0.25169
# [11]	validation_0-error:0.25460
# [12]	validation_0-error:0.24879
# [13]	validation_0-error:0.25073
# [14]	validation_0-error:0.25169
# [15]	validation_0-error:0.25169
# [16]	validation_0-error:0.25169
# [17]	validation_0-error:0.25460
# [0]	validation_0-error:0.25363
# [1]	validation_0-error:0.24879
# [2]	validation_0-error:0.24685
# [3]	validation_0-error:0.24685
# [4]	validation_0-error:0.25169
# [5]	validation_0-error:0.25266
# [6]	validation_0-error:0.24976
# [7]	validation_0-error:0.25169
# [8]	validation_0-error:0.24976
# [9]	validation_0-error:0.25169
# [10]	validation_0-error:0.25169
# [11]	validation_0-error:0.24976
# [0]	validation_0-error:0.27686
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.27299
# [3]	validation_0-error:0.27106
# [4]	validation_0-error:0.26234
# [5]	validation_0-error:0.26331
# [6]	validation_0-error:0.25847
# [7]	validation_0-error:0.25750
# [8]	validation_0-error:0.25653
# [9]	validation_0-error:0.26137
# [10]	validation_0-error:0.25847
# [11]	validation_0-error:0.25750
# [12]	validation_0-error:0.26041
# [13]	validation_0-error:0.26137
# [14]	validation_0-error:0.25750
# [15]	validation_0-error:0.25557
# [16]	validation_0-error:0.25557
# [17]	validation_0-error:0.25847
# [18]	validation_0-error:0.25847
# [19]	validation_0-error:0.25847
# [20]	validation_0-error:0.25944
# [21]	validation_0-error:0.25847
# [22]	validation_0-error:0.25847
# [23]	validation_0-error:0.25944
# [24]	validation_0-error:0.25944
# [0]	validation_0-error:0.26912
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.25073
# [4]	validation_0-error:0.25169
# [5]	validation_0-error:0.24976
# [6]	validation_0-error:0.25266
# [7]	validation_0-error:0.24976
# [8]	validation_0-error:0.25073
# [9]	validation_0-error:0.25169
# [10]	validation_0-error:0.25266
# [11]	validation_0-error:0.24976
# [12]	validation_0-error:0.24492
# [13]	validation_0-error:0.24976
# [14]	validation_0-error:0.24879
# [15]	validation_0-error:0.24976
# [16]	validation_0-error:0.24976
# [17]	validation_0-error:0.24782
# [18]	validation_0-error:0.24395
# [19]	validation_0-error:0.24298
# [20]	validation_0-error:0.24395
# [21]	validation_0-error:0.24782
# [22]	validation_0-error:0.24589
# [23]	validation_0-error:0.24395
# [24]	validation_0-error:0.24395
# [25]	validation_0-error:0.24395
# [26]	validation_0-error:0.24492
# [27]	validation_0-error:0.24395
# [28]	validation_0-error:0.24976
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.24976
# [2]	validation_0-error:0.25653
# [3]	validation_0-error:0.25847
# [4]	validation_0-error:0.25847
# [5]	validation_0-error:0.25363
# [6]	validation_0-error:0.25363
# [7]	validation_0-error:0.25363
# [8]	validation_0-error:0.25266
# [9]	validation_0-error:0.25363
# [10]	validation_0-error:0.25460
# [0]	validation_0-error:0.26815
# [1]	validation_0-error:0.25944
# [2]	validation_0-error:0.25460
# [3]	validation_0-error:0.25847
# [4]	validation_0-error:0.25847
# [5]	validation_0-error:0.25653
# [6]	validation_0-error:0.25460
# [7]	validation_0-error:0.25460
# [8]	validation_0-error:0.24782
# [9]	validation_0-error:0.24879
# [10]	validation_0-error:0.25169
# [11]	validation_0-error:0.25460
# [12]	validation_0-error:0.24879
# [13]	validation_0-error:0.25073
# [14]	validation_0-error:0.25169
# [15]	validation_0-error:0.25169
# [16]	validation_0-error:0.25169
# [17]	validation_0-error:0.25460
# [0]	validation_0-error:0.25363
# [1]	validation_0-error:0.24879
# [2]	validation_0-error:0.24685
# [3]	validation_0-error:0.24685
# [4]	validation_0-error:0.25169
# [5]	validation_0-error:0.25266
# [6]	validation_0-error:0.24976
# [7]	validation_0-error:0.25169
# [8]	validation_0-error:0.24976
# [9]	validation_0-error:0.25169
# [10]	validation_0-error:0.25169
# [11]	validation_0-error:0.24976
# [0]	validation_0-error:0.27686
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.27299
# [3]	validation_0-error:0.27106
# [4]	validation_0-error:0.26234
# [5]	validation_0-error:0.26331
# [6]	validation_0-error:0.25847
# [7]	validation_0-error:0.25750
# [8]	validation_0-error:0.25653
# [9]	validation_0-error:0.26137
# [10]	validation_0-error:0.25847
# [11]	validation_0-error:0.25750
# [12]	validation_0-error:0.26041
# [13]	validation_0-error:0.26137
# [14]	validation_0-error:0.25750
# [15]	validation_0-error:0.25557
# [16]	validation_0-error:0.25557
# [17]	validation_0-error:0.25847
# [18]	validation_0-error:0.25847
# [19]	validation_0-error:0.25847
# [20]	validation_0-error:0.25944
# [21]	validation_0-error:0.25847
# [22]	validation_0-error:0.25847
# [23]	validation_0-error:0.25944
# [24]	validation_0-error:0.25944
# [0]	validation_0-error:0.26912
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.25073
# [4]	validation_0-error:0.25169
# [5]	validation_0-error:0.24976
# [6]	validation_0-error:0.25266
# [7]	validation_0-error:0.24976
# [8]	validation_0-error:0.25073
# [9]	validation_0-error:0.25169
# [10]	validation_0-error:0.25266
# [11]	validation_0-error:0.24976
# [12]	validation_0-error:0.24492
# [13]	validation_0-error:0.24976
# [14]	validation_0-error:0.24879
# [15]	validation_0-error:0.24976
# [16]	validation_0-error:0.24976
# [17]	validation_0-error:0.24782
# [18]	validation_0-error:0.24395
# [19]	validation_0-error:0.24298
# [20]	validation_0-error:0.24395
# [21]	validation_0-error:0.24782
# [22]	validation_0-error:0.24589
# [23]	validation_0-error:0.24395
# [24]	validation_0-error:0.24395
# [25]	validation_0-error:0.24395
# [26]	validation_0-error:0.24492
# [27]	validation_0-error:0.24395
# [28]	validation_0-error:0.24976
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.24976
# [2]	validation_0-error:0.25653
# [3]	validation_0-error:0.25847
# [4]	validation_0-error:0.25847
# [5]	validation_0-error:0.25363
# [6]	validation_0-error:0.25363
# [7]	validation_0-error:0.25363
# [8]	validation_0-error:0.25266
# [9]	validation_0-error:0.25363
# [10]	validation_0-error:0.25460
# [0]	validation_0-error:0.26815
# [1]	validation_0-error:0.25944
# [2]	validation_0-error:0.25460
# [3]	validation_0-error:0.25847
# [4]	validation_0-error:0.25847
# [5]	validation_0-error:0.25653
# [6]	validation_0-error:0.25460
# [7]	validation_0-error:0.25460
# [8]	validation_0-error:0.24782
# [9]	validation_0-error:0.24879
# [10]	validation_0-error:0.25169
# [11]	validation_0-error:0.25460
# [12]	validation_0-error:0.24879
# [13]	validation_0-error:0.25073
# [14]	validation_0-error:0.25169
# [15]	validation_0-error:0.25169
# [16]	validation_0-error:0.25169
# [17]	validation_0-error:0.25460
# [0]	validation_0-error:0.25363
# [1]	validation_0-error:0.24201
# [2]	validation_0-error:0.24685
# [3]	validation_0-error:0.24395
# [4]	validation_0-error:0.25266
# [5]	validation_0-error:0.25169
# [6]	validation_0-error:0.25169
# [7]	validation_0-error:0.25169
# [8]	validation_0-error:0.25073
# [9]	validation_0-error:0.25169
# [10]	validation_0-error:0.25169
# [0]	validation_0-error:0.27686
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.27106
# [3]	validation_0-error:0.27106
# [4]	validation_0-error:0.26234
# [5]	validation_0-error:0.26525
# [6]	validation_0-error:0.25653
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25363
# [9]	validation_0-error:0.25557
# [10]	validation_0-error:0.25750
# [11]	validation_0-error:0.25266
# [12]	validation_0-error:0.25363
# [13]	validation_0-error:0.25266
# [14]	validation_0-error:0.25557
# [15]	validation_0-error:0.25169
# [16]	validation_0-error:0.25073
# [17]	validation_0-error:0.25169
# [18]	validation_0-error:0.25169
# [19]	validation_0-error:0.24976
# [20]	validation_0-error:0.24879
# [21]	validation_0-error:0.24879
# [22]	validation_0-error:0.24782
# [23]	validation_0-error:0.24976
# [24]	validation_0-error:0.24879
# [25]	validation_0-error:0.24782
# [26]	validation_0-error:0.24782
# [27]	validation_0-error:0.24782
# [28]	validation_0-error:0.24782
# [29]	validation_0-error:0.24782
# [30]	validation_0-error:0.24589
# [31]	validation_0-error:0.24782
# [32]	validation_0-error:0.24782
# [33]	validation_0-error:0.24879
# [34]	validation_0-error:0.24976
# [35]	validation_0-error:0.24976
# [36]	validation_0-error:0.24976
# [37]	validation_0-error:0.24976
# [38]	validation_0-error:0.24976
# [39]	validation_0-error:0.24976
# [40]	validation_0-error:0.24976
# [0]	validation_0-error:0.26912
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.25363
# [4]	validation_0-error:0.24976
# [5]	validation_0-error:0.24685
# [6]	validation_0-error:0.24879
# [7]	validation_0-error:0.25363
# [8]	validation_0-error:0.25363
# [9]	validation_0-error:0.25460
# [10]	validation_0-error:0.24879
# [11]	validation_0-error:0.24879
# [12]	validation_0-error:0.24685
# [13]	validation_0-error:0.24589
# [14]	validation_0-error:0.24589
# [15]	validation_0-error:0.24492
# [16]	validation_0-error:0.24782
# [17]	validation_0-error:0.24782
# [18]	validation_0-error:0.24685
# [19]	validation_0-error:0.24492
# [20]	validation_0-error:0.24492
# [21]	validation_0-error:0.24782
# [22]	validation_0-error:0.24879
# [23]	validation_0-error:0.24879
# [24]	validation_0-error:0.24782
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.24879
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.25653
# [4]	validation_0-error:0.25653
# [5]	validation_0-error:0.25363
# [6]	validation_0-error:0.25750
# [7]	validation_0-error:0.25750
# [8]	validation_0-error:0.25847
# [9]	validation_0-error:0.25750
# [10]	validation_0-error:0.25847
# [0]	validation_0-error:0.26815
# [1]	validation_0-error:0.25944
# [2]	validation_0-error:0.25460
# [3]	validation_0-error:0.25847
# [4]	validation_0-error:0.25653
# [5]	validation_0-error:0.25169
# [6]	validation_0-error:0.25363
# [7]	validation_0-error:0.25460
# [8]	validation_0-error:0.25363
# [9]	validation_0-error:0.25653
# [10]	validation_0-error:0.25169
# [11]	validation_0-error:0.24976
# [12]	validation_0-error:0.25363
# [13]	validation_0-error:0.25169
# [14]	validation_0-error:0.25460
# [15]	validation_0-error:0.25460
# [16]	validation_0-error:0.25460
# [17]	validation_0-error:0.25460
# [18]	validation_0-error:0.25266
# [19]	validation_0-error:0.24976
# [20]	validation_0-error:0.25750
# [0]	validation_0-error:0.25363
# [1]	validation_0-error:0.24201
# [2]	validation_0-error:0.24685
# [3]	validation_0-error:0.24395
# [4]	validation_0-error:0.25266
# [5]	validation_0-error:0.25169
# [6]	validation_0-error:0.25169
# [7]	validation_0-error:0.25169
# [8]	validation_0-error:0.25073
# [9]	validation_0-error:0.25169
# [10]	validation_0-error:0.25169
# [0]	validation_0-error:0.27686
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.27106
# [3]	validation_0-error:0.27106
# [4]	validation_0-error:0.26234
# [5]	validation_0-error:0.26525
# [6]	validation_0-error:0.25653
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25363
# [9]	validation_0-error:0.25557
# [10]	validation_0-error:0.25750
# [11]	validation_0-error:0.25266
# [12]	validation_0-error:0.25363
# [13]	validation_0-error:0.25266
# [14]	validation_0-error:0.25557
# [15]	validation_0-error:0.25169
# [16]	validation_0-error:0.25073
# [17]	validation_0-error:0.25169
# [18]	validation_0-error:0.25169
# [19]	validation_0-error:0.24976
# [20]	validation_0-error:0.24879
# [21]	validation_0-error:0.24879
# [22]	validation_0-error:0.24782
# [23]	validation_0-error:0.24976
# [24]	validation_0-error:0.24879
# [25]	validation_0-error:0.24782
# [26]	validation_0-error:0.24782
# [27]	validation_0-error:0.24782
# [28]	validation_0-error:0.24782
# [29]	validation_0-error:0.24782
# [30]	validation_0-error:0.24589
# [31]	validation_0-error:0.24782
# [32]	validation_0-error:0.24782
# [33]	validation_0-error:0.24879
# [34]	validation_0-error:0.24976
# [35]	validation_0-error:0.24976
# [36]	validation_0-error:0.24976
# [37]	validation_0-error:0.24976
# [38]	validation_0-error:0.24976
# [39]	validation_0-error:0.24976
# [0]	validation_0-error:0.26912
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.25363
# [4]	validation_0-error:0.24976
# [5]	validation_0-error:0.24685
# [6]	validation_0-error:0.24879
# [7]	validation_0-error:0.25363
# [8]	validation_0-error:0.25363
# [9]	validation_0-error:0.25460
# [10]	validation_0-error:0.24879
# [11]	validation_0-error:0.24879
# [12]	validation_0-error:0.24685
# [13]	validation_0-error:0.24589
# [14]	validation_0-error:0.24589
# [15]	validation_0-error:0.24492
# [16]	validation_0-error:0.24782
# [17]	validation_0-error:0.24782
# [18]	validation_0-error:0.24685
# [19]	validation_0-error:0.24492
# [20]	validation_0-error:0.24492
# [21]	validation_0-error:0.24782
# [22]	validation_0-error:0.24879
# [23]	validation_0-error:0.24879
# [24]	validation_0-error:0.24782
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.24879
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.25653
# [4]	validation_0-error:0.25653
# [5]	validation_0-error:0.25363
# [6]	validation_0-error:0.25750
# [7]	validation_0-error:0.25750
# [8]	validation_0-error:0.25847
# [9]	validation_0-error:0.25750
# [10]	validation_0-error:0.25847
# [0]	validation_0-error:0.26815
# [1]	validation_0-error:0.25944
# [2]	validation_0-error:0.25460
# [3]	validation_0-error:0.25847
# [4]	validation_0-error:0.25653
# [5]	validation_0-error:0.25169
# [6]	validation_0-error:0.25363
# [7]	validation_0-error:0.25460
# [8]	validation_0-error:0.25363
# [9]	validation_0-error:0.25653
# [10]	validation_0-error:0.25169
# [11]	validation_0-error:0.24976
# [12]	validation_0-error:0.25363
# [13]	validation_0-error:0.25169
# [14]	validation_0-error:0.25460
# [15]	validation_0-error:0.25460
# [16]	validation_0-error:0.25460
# [17]	validation_0-error:0.25460
# [18]	validation_0-error:0.25266
# [19]	validation_0-error:0.24976
# [20]	validation_0-error:0.25750
# [0]	validation_0-error:0.25363
# [1]	validation_0-error:0.24201
# [2]	validation_0-error:0.24685
# [3]	validation_0-error:0.24395
# [4]	validation_0-error:0.25266
# [5]	validation_0-error:0.25169
# [6]	validation_0-error:0.25169
# [7]	validation_0-error:0.25169
# [8]	validation_0-error:0.25073
# [9]	validation_0-error:0.25169
# [10]	validation_0-error:0.25169
# [0]	validation_0-error:0.27686
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.27106
# [3]	validation_0-error:0.27106
# [4]	validation_0-error:0.26234
# [5]	validation_0-error:0.26525
# [6]	validation_0-error:0.25653
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25363
# [9]	validation_0-error:0.25557
# [10]	validation_0-error:0.25750
# [11]	validation_0-error:0.25266
# [12]	validation_0-error:0.25363
# [13]	validation_0-error:0.25266
# [14]	validation_0-error:0.25557
# [15]	validation_0-error:0.25169
# [16]	validation_0-error:0.25073
# [17]	validation_0-error:0.25169
# [18]	validation_0-error:0.25169
# [19]	validation_0-error:0.24976
# [20]	validation_0-error:0.24879
# [21]	validation_0-error:0.24879
# [22]	validation_0-error:0.24782
# [23]	validation_0-error:0.24976
# [24]	validation_0-error:0.24879
# [25]	validation_0-error:0.24782
# [26]	validation_0-error:0.24782
# [27]	validation_0-error:0.24782
# [28]	validation_0-error:0.24782
# [29]	validation_0-error:0.24782
# [30]	validation_0-error:0.24589
# [31]	validation_0-error:0.24782
# [32]	validation_0-error:0.24782
# [33]	validation_0-error:0.24879
# [34]	validation_0-error:0.24976
# [35]	validation_0-error:0.24976
# [36]	validation_0-error:0.24976
# [37]	validation_0-error:0.24976
# [38]	validation_0-error:0.24976
# [39]	validation_0-error:0.24976
# [0]	validation_0-error:0.26912
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.25363
# [4]	validation_0-error:0.24976
# [5]	validation_0-error:0.24685
# [6]	validation_0-error:0.24879
# [7]	validation_0-error:0.25363
# [8]	validation_0-error:0.25363
# [9]	validation_0-error:0.25460
# [10]	validation_0-error:0.24879
# [11]	validation_0-error:0.24879
# [12]	validation_0-error:0.24685
# [13]	validation_0-error:0.24589
# [14]	validation_0-error:0.24589
# [15]	validation_0-error:0.24492
# [16]	validation_0-error:0.24782
# [17]	validation_0-error:0.24782
# [18]	validation_0-error:0.24685
# [19]	validation_0-error:0.24492
# [20]	validation_0-error:0.24492
# [21]	validation_0-error:0.24782
# [22]	validation_0-error:0.24879
# [23]	validation_0-error:0.24879
# [24]	validation_0-error:0.24782
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.24879
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.25653
# [4]	validation_0-error:0.25653
# [5]	validation_0-error:0.25363
# [6]	validation_0-error:0.25750
# [7]	validation_0-error:0.25750
# [8]	validation_0-error:0.25847
# [9]	validation_0-error:0.25750
# [10]	validation_0-error:0.25847
# [0]	validation_0-error:0.26815
# [1]	validation_0-error:0.25944
# [2]	validation_0-error:0.25460
# [3]	validation_0-error:0.25847
# [4]	validation_0-error:0.25653
# [5]	validation_0-error:0.25169
# [6]	validation_0-error:0.25363
# [7]	validation_0-error:0.25460
# [8]	validation_0-error:0.25363
# [9]	validation_0-error:0.25653
# [10]	validation_0-error:0.25169
# [11]	validation_0-error:0.24976
# [12]	validation_0-error:0.25363
# [13]	validation_0-error:0.25169
# [14]	validation_0-error:0.25460
# [15]	validation_0-error:0.25460
# [16]	validation_0-error:0.25460
# [17]	validation_0-error:0.25460
# [18]	validation_0-error:0.25266
# [19]	validation_0-error:0.24976
# [20]	validation_0-error:0.25750
# [0]	validation_0-error:0.25363
# [1]	validation_0-error:0.24782
# [2]	validation_0-error:0.24685
# [3]	validation_0-error:0.24395
# [4]	validation_0-error:0.24685
# [5]	validation_0-error:0.24782
# [6]	validation_0-error:0.24879
# [7]	validation_0-error:0.24685
# [8]	validation_0-error:0.24976
# [9]	validation_0-error:0.24976
# [10]	validation_0-error:0.24976
# [11]	validation_0-error:0.24976
# [12]	validation_0-error:0.25557
# [0]	validation_0-error:0.27686
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.27106
# [3]	validation_0-error:0.26912
# [4]	validation_0-error:0.26815
# [5]	validation_0-error:0.26815
# [6]	validation_0-error:0.26331
# [7]	validation_0-error:0.26234
# [8]	validation_0-error:0.26525
# [9]	validation_0-error:0.26331
# [10]	validation_0-error:0.26331
# [11]	validation_0-error:0.26137
# [12]	validation_0-error:0.25944
# [13]	validation_0-error:0.25750
# [14]	validation_0-error:0.26041
# [15]	validation_0-error:0.26041
# [16]	validation_0-error:0.26234
# [17]	validation_0-error:0.26041
# [18]	validation_0-error:0.26234
# [19]	validation_0-error:0.25944
# [20]	validation_0-error:0.25847
# ...
# [10]	validation_0-error:0.24685
# [11]	validation_0-error:0.24782
# [12]	validation_0-error:0.25169
# [13]	validation_0-error:0.24976
# [14]	validation_0-error:0.24685
# [15]	validation_0-error:0.24685
# [16]	validation_0-error:0.24492
# [17]	validation_0-error:0.24201
# [18]	validation_0-error:0.24589
# [19]	validation_0-error:0.24589
# [20]	validation_0-error:0.24976
# [21]	validation_0-error:0.24782
# [22]	validation_0-error:0.24976
# [23]	validation_0-error:0.25073
# [24]	validation_0-error:0.25363
# [25]	validation_0-error:0.24976
# [26]	validation_0-error:0.24976
# [27]	validation_0-error:0.24879
# [28]	validation_0-error:0.24976
# [29]	validation_0-error:0.24976
# [30]	validation_0-error:0.24976
# [31]	validation_0-error:0.24879
# [32]	validation_0-error:0.25266
# [33]	validation_0-error:0.24879
# [34]	validation_0-error:0.25073
# [35]	validation_0-error:0.24589
# [36]	validation_0-error:0.24492
# [37]	validation_0-error:0.24492
# [38]	validation_0-error:0.24492
# [39]	validation_0-error:0.24492
# [40]	validation_0-error:0.24492
# [41]	validation_0-error:0.24589
# [42]	validation_0-error:0.24589
# [43]	validation_0-error:0.24589
# [44]	validation_0-error:0.24589
# [45]	validation_0-error:0.24589
# [46]	validation_0-error:0.24589
# [47]	validation_0-error:0.24589
# [48]	validation_0-error:0.24589
# [49]	validation_0-error:0.24589
# [50]	validation_0-error:0.24589
# [51]	validation_0-error:0.24589
# [52]	validation_0-error:0.24589
# [53]	validation_0-error:0.24589
# [54]	validation_0-error:0.24589
# [55]	validation_0-error:0.24589
# [56]	validation_0-error:0.24589
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.25557
# [2]	validation_0-error:0.25363
# [3]	validation_0-error:0.25653
# [4]	validation_0-error:0.25944
# [5]	validation_0-error:0.25847
# [6]	validation_0-error:0.25847
# [7]	validation_0-error:0.25653
# [8]	validation_0-error:0.25557
# [9]	validation_0-error:0.25460
# [10]	validation_0-error:0.25653
# [11]	validation_0-error:0.25653
# [12]	validation_0-error:0.25557
# [13]	validation_0-error:0.25557
# [14]	validation_0-error:0.25653
# [15]	validation_0-error:0.25557
# [16]	validation_0-error:0.25557
# [17]	validation_0-error:0.25653
# [18]	validation_0-error:0.25653
# [19]	validation_0-error:0.25750
# [20]	validation_0-error:0.25750
# [21]	validation_0-error:0.26041
# [22]	validation_0-error:0.26041
# [23]	validation_0-error:0.25944
# [24]	validation_0-error:0.25944
# [25]	validation_0-error:0.26137
# [26]	validation_0-error:0.25653
# [27]	validation_0-error:0.25557
# [28]	validation_0-error:0.25557
# [29]	validation_0-error:0.25460
# [30]	validation_0-error:0.25460
# [31]	validation_0-error:0.25363
# [32]	validation_0-error:0.25073
# [33]	validation_0-error:0.25073
# [34]	validation_0-error:0.25073
# [35]	validation_0-error:0.25073
# [36]	validation_0-error:0.25073
# [37]	validation_0-error:0.25073
# [38]	validation_0-error:0.25073
# [39]	validation_0-error:0.25073
# [40]	validation_0-error:0.25073
# [41]	validation_0-error:0.25073
# [42]	validation_0-error:0.25073
# [43]	validation_0-error:0.25073
# [44]	validation_0-error:0.25169
# [45]	validation_0-error:0.25169
# [46]	validation_0-error:0.25169
# [47]	validation_0-error:0.25169
# [48]	validation_0-error:0.25169
# [49]	validation_0-error:0.25169
# [50]	validation_0-error:0.25169
# [51]	validation_0-error:0.25169
# [52]	validation_0-error:0.25169
# [53]	validation_0-error:0.25169
# [54]	validation_0-error:0.25169
# [55]	validation_0-error:0.25169
# [56]	validation_0-error:0.25169
# [57]	validation_0-error:0.25169
# [58]	validation_0-error:0.25169
# [59]	validation_0-error:0.25169
# [60]	validation_0-error:0.25169
# [61]	validation_0-error:0.25169
# [62]	validation_0-error:0.25169
# [63]	validation_0-error:0.25169
# [64]	validation_0-error:0.25169
# [65]	validation_0-error:0.25169
# [66]	validation_0-error:0.25169
# [67]	validation_0-error:0.25169
# [68]	validation_0-error:0.25169
# [69]	validation_0-error:0.25169
# [70]	validation_0-error:0.25169
# [71]	validation_0-error:0.25169
# [0]	validation_0-error:0.26041
# [1]	validation_0-error:0.26137
# [2]	validation_0-error:0.26041
# [3]	validation_0-error:0.25750
# [4]	validation_0-error:0.25557
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.25557
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25557
# [9]	validation_0-error:0.25073
# [10]	validation_0-error:0.24879
# [11]	validation_0-error:0.25073
# [12]	validation_0-error:0.25266
# [13]	validation_0-error:0.25266
# [14]	validation_0-error:0.25363
# [15]	validation_0-error:0.25169
# [16]	validation_0-error:0.25363
# [17]	validation_0-error:0.25363
# [18]	validation_0-error:0.25363
# [19]	validation_0-error:0.25460
# [20]	validation_0-error:0.25557
# [21]	validation_0-error:0.25266
# [22]	validation_0-error:0.25460
# [23]	validation_0-error:0.25363
# [24]	validation_0-error:0.25557
# [25]	validation_0-error:0.25460
# [26]	validation_0-error:0.25557
# [27]	validation_0-error:0.26234
# [28]	validation_0-error:0.26137
# [29]	validation_0-error:0.26137
# [30]	validation_0-error:0.26137
# [31]	validation_0-error:0.26041
# [32]	validation_0-error:0.25847
# [33]	validation_0-error:0.25847
# [34]	validation_0-error:0.25847
# [35]	validation_0-error:0.25847
# [36]	validation_0-error:0.25847
# [37]	validation_0-error:0.25847
# [38]	validation_0-error:0.25847
# [39]	validation_0-error:0.25847
# [40]	validation_0-error:0.25847
# [41]	validation_0-error:0.25847
# [42]	validation_0-error:0.25847
# [43]	validation_0-error:0.25847
# [44]	validation_0-error:0.25847
# [45]	validation_0-error:0.25847
# [46]	validation_0-error:0.25847
# [47]	validation_0-error:0.25944
# [48]	validation_0-error:0.25944
# [49]	validation_0-error:0.25944
# [50]	validation_0-error:0.25944
# [0]	validation_0-error:0.23814
# [1]	validation_0-error:0.23717
# [2]	validation_0-error:0.25169
# [3]	validation_0-error:0.25169
# [4]	validation_0-error:0.25169
# [5]	validation_0-error:0.25073
# [6]	validation_0-error:0.25169
# [7]	validation_0-error:0.25169
# [8]	validation_0-error:0.25169
# [9]	validation_0-error:0.24879
# [10]	validation_0-error:0.24879
# [11]	validation_0-error:0.24879
# [12]	validation_0-error:0.24492
# [13]	validation_0-error:0.24589
# [14]	validation_0-error:0.24589
# [15]	validation_0-error:0.24589
# [16]	validation_0-error:0.24782
# [17]	validation_0-error:0.24589
# [18]	validation_0-error:0.24395
# [19]	validation_0-error:0.24298
# [20]	validation_0-error:0.24201
# [21]	validation_0-error:0.24685
# [22]	validation_0-error:0.24589
# [23]	validation_0-error:0.24685
# [24]	validation_0-error:0.24685
# [25]	validation_0-error:0.24782
# [26]	validation_0-error:0.25363
# [27]	validation_0-error:0.25266
# [28]	validation_0-error:0.25266
# [29]	validation_0-error:0.25363
# [30]	validation_0-error:0.25363
# [31]	validation_0-error:0.25460
# [32]	validation_0-error:0.25169
# [33]	validation_0-error:0.25460
# [34]	validation_0-error:0.25266
# [35]	validation_0-error:0.25363
# [36]	validation_0-error:0.25266
# [37]	validation_0-error:0.25266
# [38]	validation_0-error:0.25169
# [39]	validation_0-error:0.25169
# [40]	validation_0-error:0.25266
# [0]	validation_0-error:0.27202
# [1]	validation_0-error:0.27106
# [2]	validation_0-error:0.26621
# [3]	validation_0-error:0.27106
# [4]	validation_0-error:0.26621
# [5]	validation_0-error:0.26718
# [6]	validation_0-error:0.26718
# [7]	validation_0-error:0.26621
# [8]	validation_0-error:0.26428
# [9]	validation_0-error:0.26041
# [10]	validation_0-error:0.25750
# [11]	validation_0-error:0.25847
# [12]	validation_0-error:0.25653
# [13]	validation_0-error:0.25557
# [14]	validation_0-error:0.25460
# [15]	validation_0-error:0.25557
# [16]	validation_0-error:0.25653
# [17]	validation_0-error:0.25557
# [18]	validation_0-error:0.26041
# [19]	validation_0-error:0.26041
# [20]	validation_0-error:0.25847
# [21]	validation_0-error:0.25944
# [22]	validation_0-error:0.26041
# [23]	validation_0-error:0.25944
# [24]	validation_0-error:0.25944
# [25]	validation_0-error:0.25653
# [26]	validation_0-error:0.25847
# [27]	validation_0-error:0.25944
# [28]	validation_0-error:0.25847
# [29]	validation_0-error:0.25750
# [30]	validation_0-error:0.25557
# [31]	validation_0-error:0.25557
# [32]	validation_0-error:0.25557
# [33]	validation_0-error:0.25557
# [34]	validation_0-error:0.25557
# [35]	validation_0-error:0.25557
# [36]	validation_0-error:0.25557
# [37]	validation_0-error:0.25557
# [38]	validation_0-error:0.25557
# [39]	validation_0-error:0.25557
# [40]	validation_0-error:0.25557
# [41]	validation_0-error:0.25653
# [42]	validation_0-error:0.25653
# [43]	validation_0-error:0.25653
# [44]	validation_0-error:0.25653
# [45]	validation_0-error:0.25653
# [46]	validation_0-error:0.25653
# [47]	validation_0-error:0.25653
# [48]	validation_0-error:0.25653
# [49]	validation_0-error:0.25653
# [50]	validation_0-error:0.25653
# [51]	validation_0-error:0.25653
# [52]	validation_0-error:0.25653
# [53]	validation_0-error:0.25653
# [0]	validation_0-error:0.27106
# [1]	validation_0-error:0.26718
# [2]	validation_0-error:0.25557
# [3]	validation_0-error:0.25266
# [4]	validation_0-error:0.25169
# [5]	validation_0-error:0.25169
# [6]	validation_0-error:0.24782
# [7]	validation_0-error:0.24782
# [8]	validation_0-error:0.24879
# [9]	validation_0-error:0.24879
# [10]	validation_0-error:0.24685
# [11]	validation_0-error:0.24782
# [12]	validation_0-error:0.25169
# [13]	validation_0-error:0.24976
# [14]	validation_0-error:0.24685
# [15]	validation_0-error:0.24685
# [16]	validation_0-error:0.24492
# [17]	validation_0-error:0.24201
# [18]	validation_0-error:0.24589
# [19]	validation_0-error:0.24589
# [20]	validation_0-error:0.24976
# [21]	validation_0-error:0.24782
# [22]	validation_0-error:0.24976
# [23]	validation_0-error:0.25073
# [24]	validation_0-error:0.25363
# [25]	validation_0-error:0.24976
# [26]	validation_0-error:0.24976
# [27]	validation_0-error:0.24879
# [28]	validation_0-error:0.24976
# [29]	validation_0-error:0.24976
# [30]	validation_0-error:0.24976
# [31]	validation_0-error:0.24879
# [32]	validation_0-error:0.25266
# [33]	validation_0-error:0.24879
# [34]	validation_0-error:0.25073
# [35]	validation_0-error:0.24589
# [36]	validation_0-error:0.24492
# [37]	validation_0-error:0.24492
# [38]	validation_0-error:0.24492
# [39]	validation_0-error:0.24492
# [40]	validation_0-error:0.24492
# [41]	validation_0-error:0.24589
# [42]	validation_0-error:0.24589
# [43]	validation_0-error:0.24589
# [44]	validation_0-error:0.24589
# [45]	validation_0-error:0.24589
# [46]	validation_0-error:0.24589
# [47]	validation_0-error:0.24589
# [48]	validation_0-error:0.24589
# [49]	validation_0-error:0.24589
# [50]	validation_0-error:0.24589
# [51]	validation_0-error:0.24589
# [52]	validation_0-error:0.24589
# [53]	validation_0-error:0.24589
# [54]	validation_0-error:0.24589
# [55]	validation_0-error:0.24589
# [56]	validation_0-error:0.24589
# [0]	validation_0-error:0.25460
# [1]	validation_0-error:0.25557
# [2]	validation_0-error:0.25363
# [3]	validation_0-error:0.25653
# [4]	validation_0-error:0.25944
# [5]	validation_0-error:0.25847
# [6]	validation_0-error:0.25847
# [7]	validation_0-error:0.25653
# [8]	validation_0-error:0.25557
# [9]	validation_0-error:0.25460
# [10]	validation_0-error:0.25653
# [11]	validation_0-error:0.25653
# [12]	validation_0-error:0.25557
# [13]	validation_0-error:0.25557
# [14]	validation_0-error:0.25653
# [15]	validation_0-error:0.25557
# [16]	validation_0-error:0.25557
# [17]	validation_0-error:0.25653
# [18]	validation_0-error:0.25653
# [19]	validation_0-error:0.25750
# [20]	validation_0-error:0.25750
# [21]	validation_0-error:0.26041
# [22]	validation_0-error:0.26041
# [23]	validation_0-error:0.25944
# [24]	validation_0-error:0.25944
# [25]	validation_0-error:0.26137
# [26]	validation_0-error:0.25653
# [27]	validation_0-error:0.25557
# [28]	validation_0-error:0.25557
# [29]	validation_0-error:0.25460
# [30]	validation_0-error:0.25460
# [31]	validation_0-error:0.25363
# [32]	validation_0-error:0.25073
# [33]	validation_0-error:0.25073
# [34]	validation_0-error:0.25073
# [35]	validation_0-error:0.25073
# [36]	validation_0-error:0.25073
# [37]	validation_0-error:0.25073
# [38]	validation_0-error:0.25073
# [39]	validation_0-error:0.25073
# [40]	validation_0-error:0.25073
# [41]	validation_0-error:0.25073
# [42]	validation_0-error:0.25073
# [43]	validation_0-error:0.25073
# [44]	validation_0-error:0.25169
# [45]	validation_0-error:0.25169
# [46]	validation_0-error:0.25169
# [47]	validation_0-error:0.25169
# [48]	validation_0-error:0.25169
# [49]	validation_0-error:0.25169
# [50]	validation_0-error:0.25169
# [51]	validation_0-error:0.25169
# [52]	validation_0-error:0.25169
# [53]	validation_0-error:0.25169
# [54]	validation_0-error:0.25169
# [55]	validation_0-error:0.25169
# [56]	validation_0-error:0.25169
# [57]	validation_0-error:0.25169
# [58]	validation_0-error:0.25169
# [59]	validation_0-error:0.25169
# [60]	validation_0-error:0.25169
# [61]	validation_0-error:0.25169
# [62]	validation_0-error:0.25169
# [63]	validation_0-error:0.25169
# [64]	validation_0-error:0.25169
# [65]	validation_0-error:0.25169
# [66]	validation_0-error:0.25169
# [67]	validation_0-error:0.25169
# [68]	validation_0-error:0.25169
# [69]	validation_0-error:0.25169
# [70]	validation_0-error:0.25169
# [71]	validation_0-error:0.25169
# [0]	validation_0-error:0.26041
# [1]	validation_0-error:0.26137
# [2]	validation_0-error:0.26041
# [3]	validation_0-error:0.25750
# [4]	validation_0-error:0.25557
# [5]	validation_0-error:0.25557
# [6]	validation_0-error:0.25557
# [7]	validation_0-error:0.25847
# [8]	validation_0-error:0.25557
# [9]	validation_0-error:0.25073
# [10]	validation_0-error:0.24879
# [11]	validation_0-error:0.25073
# [12]	validation_0-error:0.25266
# [13]	validation_0-error:0.25266
# [14]	validation_0-error:0.25363
# [15]	validation_0-error:0.25169
# [16]	validation_0-error:0.25363
# [17]	validation_0-error:0.25363
# [18]	validation_0-error:0.25363
# [19]	validation_0-error:0.25460
# [20]	validation_0-error:0.25557
# [21]	validation_0-error:0.25266
# [22]	validation_0-error:0.25460
# [23]	validation_0-error:0.25363
# [24]	validation_0-error:0.25557
# [25]	validation_0-error:0.25460
# [26]	validation_0-error:0.25557
# [27]	validation_0-error:0.26234
# [28]	validation_0-error:0.26137
# [29]	validation_0-error:0.26137
# [30]	validation_0-error:0.26137
# [31]	validation_0-error:0.26041
# [32]	validation_0-error:0.25847
# [33]	validation_0-error:0.25847
# [34]	validation_0-error:0.25847
# [35]	validation_0-error:0.25847
# [36]	validation_0-error:0.25847
# [37]	validation_0-error:0.25847
# [38]	validation_0-error:0.25847
# [39]	validation_0-error:0.25847
# [40]	validation_0-error:0.25847
# [41]	validation_0-error:0.25847
# [42]	validation_0-error:0.25847
# [43]	validation_0-error:0.25847
# [44]	validation_0-error:0.25847
# [45]	validation_0-error:0.25847
# [46]	validation_0-error:0.25847
# [47]	validation_0-error:0.25944
# [48]	validation_0-error:0.25944
# [49]	validation_0-error:0.25944
# [0]	validation_0-error:0.24492
# [1]	validation_0-error:0.24105
# [2]	validation_0-error:0.24879
# [3]	validation_0-error:0.24492
# [4]	validation_0-error:0.24395
# [5]	validation_0-error:0.24492
# [6]	validation_0-error:0.24782
# [7]	validation_0-error:0.25363
# [8]	validation_0-error:0.24492
# [9]	validation_0-error:0.25460
# [10]	validation_0-error:0.25460
# [11]	validation_0-error:0.25363
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=111, ...),
#              param_grid={'early_stopping_rounds': [10, 20, 40],
#                          'eval_metric': ['error'], 'gamma': [6, 7, 8],
#                          'learning_rate': [0.07, 0.08, 0.09],
#                          'max_depth': [30, 40, 50]},
#              verbose=1)

# %%
# Testing optimised XGboost model
clf_xgb_optimised = clf_xgb_grid.best_estimator_
clf_xgb_optimised.fit(X_train, y_train, eval_set= eval_set)
# Out:
# [0]	validation_0-error:0.21278	validation_1-error:0.24492
# [1]	validation_0-error:0.20939	validation_1-error:0.24105
# [2]	validation_0-error:0.20697	validation_1-error:0.24879
# [3]	validation_0-error:0.21206	validation_1-error:0.24492
# [4]	validation_0-error:0.21060	validation_1-error:0.24395
# [5]	validation_0-error:0.21206	validation_1-error:0.24492
# [6]	validation_0-error:0.21060	validation_1-error:0.24782
# [7]	validation_0-error:0.21060	validation_1-error:0.25363
# [8]	validation_0-error:0.20915	validation_1-error:0.24492
# [9]	validation_0-error:0.20842	validation_1-error:0.25460
# [10]	validation_0-error:0.20988	validation_1-error:0.25460
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=10, enable_categorical=False,
#               eval_metric='error', feature_types=None, gamma=7, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.07, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=30, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=111, ...)

# %%
# Calculate metrics score
y_pred = clf_xgb_optimised.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

# Plotting confusion matrix heatmap
fig, heatmap_cm = plt.subplots(figsize=(4,4))
sns.heatmap(cm, annot=True, fmt=".1f", ax=heatmap_cm, annot_kws={"fontsize":15})
heatmap_cm.set(xlabel="Predicted movement", ylabel="Actual movement")
heatmap_cm.set_title("Heatmap of optimised XG boost optimised confusion matrix", fontsize=10)

# Store metrics values into dataframe
optimised_metrics_df["optimised XB boost"] = [accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        log_loss(y_test, clf_xgb_optimised.predict_proba(X_test)[:,1]),
                                        roc_auc_score(y_test, clf_xgb_optimised.predict_proba(X_test)[:,1])]

# %% [markdown]
# ### 4 Stacking model together in one ensemble model
# Models used here are the best four performing models: XGBClassifier, RandomForestClassifier, SCV and LogisticRegression
# <br>
# Stacked model will be compare with voting classifier model

# %%
from sklearn.ensemble import StackingClassifier

# %%
# Inputting estimator to be used
estimators = [("clf_xgb_optimised", xgb.XGBClassifier(random_state = 111, objective = 'binary:logistic', max_depth = 30, learning_rate = 0.08, eval_metric = "error", gamma = 7)),
            ("clf_rf_optimised", clf_rf_optimised),
            ("clf_svc_optimised", clf_svc_optimised),
            ("clf_lr", LogisticRegression())
]

# %%
# Testing of ensemble model
clf_stack = StackingClassifier(estimators=estimators, final_estimator=SVC(C=10, gamma=20, probability=True, random_state=111))
clf_stack.fit(X_train, y_train)
y_pred = clf_stack.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

# Plotting confusion matrix heatmap
fig, heatmap_cm = plt.subplots(figsize=(4,4))
sns.heatmap(cm, annot=True, fmt=".1f", ax=heatmap_cm, annot_kws={"fontsize":15})
heatmap_cm.set(xlabel="Predicted movement", ylabel="Actual movement")
heatmap_cm.set_title("Heatmap of stacking classifier confusion matrix", fontsize=10)

# Store metrics values into dataframe
optimised_metrics_df["Stacking model"] = [accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        log_loss(y_test, clf_stack.predict_proba(X_test)[:,1]),
                                        roc_auc_score(y_test,clf_stack.predict_proba(X_test)[:,1])]

# %% [markdown]
# ### 4.1.5 Stacking model together using voting classifier

# %%
# create the sub models
estimators = []

estimators.append(('LogReg', clf_lr))
estimators.append(('RanF', clf_rf_optimised))
estimators.append(('SVC', clf_svc))
estimators.append(('xgb', (xgb.XGBClassifier(random_state = 111, objective = 'binary:logistic', max_depth = 30, learning_rate = 0.08, eval_metric = "error", gamma = 7))))

# %%
# Using VotingClassifier() to build ensemble model with Hard Voting
clf_hv = VotingClassifier(estimators)
clf_hv.fit(X_train,y_train)

# Predicting labels
y_pred = clf_hv.predict(X_test) 

# Plotting confusion matrix heatmap
cm = confusion_matrix(y_test, y_pred)
fig, heatmap_cm = plt.subplots(figsize=(4,4))
sns.heatmap(cm, annot=True, fmt=".1f",  ax=heatmap_cm, annot_kws={"fontsize":15})
heatmap_cm.set(xlabel="Predicted movement", ylabel="Actual movement")
heatmap_cm.set_title("Heatmap of hard voting confusion matrix", fontsize=10)

# Store metrics values into dataframe
optimised_metrics_df["Voting classifier"] = [accuracy_score(y_test, y_pred),
                                            precision_score(y_test, y_pred),
                                            np.nan,
                                            np.nan]

# %% [markdown]
# ## 4.2 Plotting and comparing models

# %%
# Plotting metrics of ML models
fig, comparison_ax = plt.subplots(figsize=(15,13))
optimised_metrics_df.plot(kind="bar", xlabel="Metrics measurement used", ylabel="Measurement", title="Metrics comparision of models",ax=comparison_ax)
# Out:
# <AxesSubplot:title={'center':'Metrics comparision of models'}, xlabel='Metrics measurement used', ylabel='Measurement'>

# %% [markdown]
# # 5. Backtest of validation data
# Data from 2022 onwards have not been seen by any model yet as it is set as validation data<br>
# Final model will be used to predict on validation data and expecting accuracy to be similar to train test data<br>
# Backtest will be done on the validation date with the following strategy and assumption<br>
# -If currently no position in market, will take up the first prediction direction(long/short)<br>
# -If currently position is in market, will check next prediction whether is it the same as currently position(buy prediction with current long position)<br>
# -If next prediction is not in favour of current position(sell prediction with current long position), will exit current position and take up the prediction direction(sell current long position and sell again to take up a short position)<br>
# -Assuming buy and sell price is exactly at closing price of the prediction appear

# %% [markdown]
# ## 5.1 Validating 2022 data with final model and compare metrics

# %%
# Testing of validation data
X_valid = sti_df_validation[['ema_period_5_diff', 'stochastic_period_5', 'force_index_5', 'macd_diff', 'stochastic_period_10']]
y_valid = sti_df_validation["Next_day_movement"]

#  Transform X data into standardised data
X_valid = sc.transform(X_valid)

# %%
# Predict label with the validation data
y_predict = clf_stack.predict(X_valid)

# Calculate metrics score
print("Accuracy score:", accuracy_score(y_valid, y_predict))   
print("Precision score:",precision_score(y_valid, y_predict))
print("Log_loss:",log_loss(y_valid, clf_stack.predict_proba(X_valid)[:,1])) 
print(f"AUC score: {roc_auc_score(y_valid, clf_stack.predict_proba(X_valid)[:,1])}") 

# Plotting confusion matrix heatmap
cm = confusion_matrix(y_valid, y_predict)
fig, heatmap_cm = plt.subplots(figsize=(8,5))
sns.heatmap(cm, annot=True, fmt=".1f",  ax=heatmap_cm, annot_kws={"fontsize":20})
heatmap_cm.set(xlabel="Predicted movement", ylabel="Actual movement")
heatmap_cm.set_title("Heatmap of validation data confusion matrix", fontsize=15)
# Out:
# Accuracy score: 0.7652173913043478
# Precision score: 0.7966101694915254
# Log_loss: 0.535697385373339
# AUC score: 0.8057668898356666
# Text(0.5, 1.0, 'Heatmap of validation data confusion matrix')

# %%
# Append predicted labels to date and closing price
back_test = sti_df_validation[["Date","Close","Next_day_movement"]]
back_test["Predict"] = y_predict
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2756\3440699354.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   back_test["Predict"] = y_predict

# %% [markdown]
# ## 5.2 Testing of predicted values in a buy or sell situation

# %%
# Simulate buy or sell scenario with prediction from model on 2022 data
current_position = 0 # Start off with no position in market
long_position_prices = [] # To store buy prices and exit prices
short_position_prices = [] # To store sell prices and exit prices
long_position_date = [] # To store buy and exit dates
short_position_date =[] # To store buy and exit dates

for prediction, price, date in zip(back_test["Predict"], back_test["Close"], back_test["Date"]):
    if current_position == 0 and  prediction == 0: # No position with sell prediction
        current_position = -1
        short_position_prices.append(price)
        short_position_date.append(date)

    elif current_position == 0 and  prediction == 1: # No position with buy prediction
        current_position = 1
        long_position_prices.append(price)
        long_position_date.append(date)

    elif current_position == 1 and  prediction == 0: # Currently with long position with sell prediction
        current_position = -1
        long_position_prices.append(price) # Sell current long position
        long_position_prices.append(np.nan)
        long_position_date.append(date)
        long_position_date.append(np.nan)
        short_position_prices.append(price) # Enter new short position
        short_position_date.append(date)

    elif current_position == -1 and  prediction == 1: # Currently with short position with buy prediction
        current_position = 1
        short_position_prices.append(price) # Buy back current short position
        short_position_prices.append(np.nan) 
        short_position_date.append(date)
        short_position_date.append(np.nan)
        long_position_prices.append(price) # Enter new long position
        long_position_date.append(date)

# %%
# Combine long and short dates to prices
short_position = pd.DataFrame()
long_position = pd.DataFrame()
short_position["Date"] = short_position_date
long_position["Date"] = long_position_date
short_position["Price"] = short_position_prices
long_position["Price"] = long_position_prices

# %%
# Import libraries for plotting
import plotly.graph_objs as go
import plotly.offline as offline

# %%
# Trace for short positions
trace0 = go.Scatter(
    
    x = short_position["Date"],
    y = short_position["Price"],
    
    name = 'Short positions',
    
    line = dict(color = ('red'),
                width = 2)
)

# Trace for short positions
trace1 = go.Scatter(
    
    x = long_position["Date"],
    y = long_position["Price"],
    
    name = 'Long positions',
    
    line = dict(color = ('blue'),
                width = 2)
)

# Trace for closing price
trace2 = go.Scatter(
    
    x = sti_df_validation["Date"],
    y = sti_df_validation["Close"],
    
    name = 'Closing price',
    
    line = dict(color = ('green'),
                width = 1),
)

# %%
# Plotting out entry and exits done
data = [trace0, trace1, trace2]

layout = dict(title = 'Backtesting of 2022 data',
              xaxis = dict(title = 'Date'),
              yaxis = dict(title = 'Price'),
              )

fig = dict(data=data, layout=layout)

offline.iplot(fig)

# %%
# Finding the profit by finding the difference and filter out by dropping the nan
buy = long_position["Price"].diff().dropna()
sell = short_position["Price"].diff().dropna()*-1 # Change profit to a positive number as it is shorting trades

# Results of total trades perform by buys, sells, total profit
print("Number of trades", len(buy)+len(sell))
print("Number of buy trades is ", len(buy), "and number of sell trades", len(sell))
print("Profit from long positions", buy.sum())
print("Profit from short positions", sell.sum())
print("Total profit", buy.sum() + sell.sum())
# Out:
# Number of trades 50
# Number of buy trades is  25 and number of sell trades 25
# Profit from long positions 450.0703125
# Profit from short positions 307.960205078125
# Total profit 758.030517578125
